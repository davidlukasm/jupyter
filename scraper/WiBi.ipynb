# %%
import re
import csv
import requests
import urllib
import json
import html
import time
from bs4 import BeautifulSoup

report_url_base = "https://suasprod.noc-science.at/XLCubedWeb/WebForm/ShowReport.aspx?rep="

indicators = { "1.C.1": {'name': "1.C.1", 'desc': "Drittmittelerlöse",
                         'report_path': "009 wissensbilanzen universitäten/003 intellektuelles vermögen - strukturkapital/002 1-c-1 erlöse forschung und entwicklung-projekte - projekte eek.xml",
                         'dimensions': ["Universitätsausrichtung", "Fördergeber", "Sitz", "Disziplin", "WZW"]},
               "1.C.2": {'name': "1.C.2", 'desc': "Forschungsinfrastruktusr",
                         'report_path': "009 wissensbilanzen universitäten/003 intellektuelles vermögen - strukturkapital/003 1-c-2 investitionen in infrastruktur im f und e bereich.xml",
                         'dimensions': ["Art der FI", "Disziplin", "WZW"]},
               "2.B.1": {'name': "2.B.1", 'desc': "Strukturierte Doktorate",
                         'report_path': "009 wissensbilanzen universitäten/005 kernprozesse - forschung und entwicklung entwicklung und erschließung der künste/002 2-b-1 doktoratsstudierende mit beschäftigungsverhältnis zur universität.xml",
                         'dimensions': ["Personalkategorie", "Staat", "Universitätsausrichtung"]},
               "3.B.1": {'name': "3.B.1", 'desc': "Publikationen",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/001 3-b-1 wissenschaftliche künstlerische veröffentlichungen.xml",
                         'dimensions': ["WZW", "Disziplin", "Publikationstyp", "Universitätsausrichtung"]},
               "3.B.2": {'name': "3.B.2", 'desc': "Vorträge",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/002 3-b-2 gehaltene vorträge präsentationen.xml",
                         'dimensions': ["WZW", "Disziplin", "Veranstaltungstypus", "Vortragstypus", "Universitätsausrichtung"]},
               "3.B.3": {'name': "3.B.3", 'desc': "Patente",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/003 3-b-3 anzahl der patentanmeldungen.xml",
                         'dimensions': ["Transferleistung"]}}
for indicator in indicators.values():
    indicator['report_url'] = report_url_base + urllib.parse.quote(indicator['report_path'])
    
def create_filename(name, groups):
    return name + '_' + '_'.join(groups) + '.csv'
    
class Unidata:
    workbook = "https://suasprod.noc-science.at/XLCubedWeb/WebServices/WorkbookService.svc/"
    university_class = 's22'
    value_class = 's39'
    aggregate_category = 'Gesamt'
    years = {"2018": 0, "2017": 2, "2016": 4}
    cookie = None
    headers = {
        'Accept': '*/*',
        'Connection': 'keep-alive',
        'Host': 'suasprod.noc-science.at',
        'X-Requested-With': 'XMLHttpRequest',
        'Content-Type': 'application/json; charset=utf-8',
        'Cookie': None,   
    }
    
    def __init__(self):
        self.load_url = self.workbook + "LoadAndRender"
        self.update_url = self.workbook + "UpdateAndRender"
    
    def create_table(self, indicator_name):
        indicator = indicators[indicator_name]
        print("Connecting to uni:data")
        if self.cookie is None:
            report_url = indicator['report_url']
            response = requests.get(report_url)
            self.cookie = response.headers['Set-Cookie'][:response.headers['Set-Cookie'].find(';')]
            self.headers['Cookie'] = self.cookie
        
        print("Creating table")
        report_path = indicator['report_path']
        data = {"Path":report_path,
                "renderMode":0,"Dpi":96,
                "ParameterNames":["rep"],
                "ParameterValues":[report_path]}
        r = requests.post(self.load_url, headers=self.headers, data=json.dumps(data))
        answer = r.json()
        return Table(self, indicator, answer)
    
class Table:
    def __init__(self, unidata, indicator, answer):
        self.unidata = unidata
        self.indicator = indicator
        tabID_find = "this.TabID = \""
        tabID = answer['d'][2]
        tabID = tabID[tabID.find(tabID_find)+len(tabID_find):tabID.find(tabID_find) + len(tabID_find) + 36]
        self.tableID = tabID
        self.groups = self.__get_groups(BeautifulSoup(answer['d'][0]))

    def __get_groups(self, soup):
        groups = {}
        for dim_id, dim_name in enumerate(self.indicator['dimensions']):
            dimslice = soup.find('div',attrs={'class': 'dimslice', 'dimensionslicerid': dim_id})
            groups[dim_name] = {'uid': dimslice['guid'],
                                'categories': {}}
            for idx, option in enumerate(dimslice.find_all('option')):
                if idx == 0:
                    groups[dim_name]['default_category'] = option['value']
                option_name = option.text
                i = 2
                while option_name in groups[dim_name]['categories']:
                    option_name = option.text + ' (' + str(i) + ')'
                    i+=1
                groups[dim_name]['categories'][option_name] = option['value']
        return groups
    
    def __change_category (self, group, category):
        data = {"TabID": self.tableID,
                "ReportPath": self.indicator['report_path'],
                "ServerEvent":"DimensionSlicerChanged",
                "ReportPathWithParameters": "null",
                "Names":["_Guid","_Member","_chartprops","_mapprops"],
                "Values":[group['uid'], category,"",""]}
        retval = requests.post(self.unidata.update_url, headers=self.unidata.headers, data=json.dumps(data))  
        time.sleep(0.6)
        return retval
    
    def __reset_group (self, group): 
        if self.unidata.aggregate_category in group['categories']:
            return self.__change_category(group, group['categories'][self.unidata.aggregate_category])
        else:
            return self.__change_category(group, group['default_category'])
    
    def __get_data_soup (self, group, category):   
        r = self.__change_category(group, category)
        answer = r.json()
        soup = BeautifulSoup(answer['d'][0])
        return soup
            
    def __get_table_data(self, soup):
        universities = {}
        for entry in soup.find_all('td', class_=self.unidata.university_class):
            values = entry.find_next_siblings('td', class_=self.unidata.value_class)
            university = {}
            for year, year_column in self.unidata.years.items():
                try:
                    university[year] = int(re.sub('[^\-0-9]','', values[year_column].text))
                except:
                    university[year] = None
            universities[entry.text.strip()] = university      
        return universities    

    def __get_data (self, groups, level = 0):
        assert(len(groups) >= 1)
        group = self.groups[groups[0]]
        data = {}
        for cat_name, cat_id in group['categories'].items():
            print('\t'*level + cat_name)
            if len(groups) == 1:
                soup = self.__get_data_soup(group, cat_id)
                data[cat_name] = self.__get_table_data(soup)
            else:
                self.__change_category(group, cat_id)
                data[cat_name] = self.__get_data(groups[1:], level+1)
                
        self.__reset_group(group)
        return data    
    
    def __save_rows_helper(data, higher_groups, groups, csvw):            
        for group_name, group in data.items():
            if len(groups) == 0:
                uni_name = group_name
                for year_name, value in group.items():
                    if value is not None:
                        csvw.writerow(higher_groups + [uni_name, year_name, value])
                        print(higher_groups + [uni_name, year_name, value])
            else:
                Table.__save_rows_helper(group, higher_groups+[group_name], groups[1:], csvw)

    def __save_table_helper (data, groups, csvw):
        csvw.writerow(groups + ['Universität', 'Jahr', 'Wert'])
        groups.reverse()
        return Table.__save_rows_helper(data, [], groups, csvw)
    
    def download_all(self, groups, filename=None):
        print("Downloading data")
        data = self.__get_data(groups)
        if filename is None:
            filename = create_filename(indicator['name'], groups)
        with open(filename, 'w') as csv_file:
            csvw = csv.writer(csv_file, delimiter=';')
            Table.__save_table_helper(data, groups, csvw)
        return filename

# %%
import ipywidgets as widgets
import os
from IPython.display import display
from IPython.display import FileLink, FileLinks, Javascript


    
class Selector:
    indicator_selector = widgets.Dropdown(
        options = [('Auswählen...', -1)] +
                  [(indicator['name']+' - '+indicator['desc'], indicator['name']) for indicator in indicators.values()],
    )
    dimension_selector = widgets.SelectMultiple(
        options = [('Bitte zuerst Kennzahl auswählen', -1)]
    )
    execute_button = widgets.Button(
        description='Laden', disabled=True,
        tooltip = 'Bitte Indikator und Dimensionen auswählen',
        button_style='info'
    )
    filename_text = widgets.Text(placeholder='Dateiname')
        
    indicator = None
    dimensions = None
    
    def indicator_selected(self, ind_sel):
        self.indicator = indicators[ind_sel['new']]
        self.dimension_selector.options = [(dim_name, idx) for idx, dim_name in enumerate(self.indicator['dimensions'])]

    def dimension_selected(self, dim_sel):
        self.dimensions = list(dim_sel['new'])
        if len(self.dimensions) == 0:
            self.execute_button.disabled = True
            self.execute_button.tooltip = 'Bitte Indikator und Dimensionen auswählen'
        else:
            self.execute_button.disabled = False
            self.execute_button.tooltip = 'Daten herunterladen'
            self.filename_text.value = create_filename(self.indicator['name'], [self.indicator['dimensions'][i] for i in self.dimensions])
        
    def execute(self, button):
        self.execute_button.disabled = True
        self.save()
        display(Javascript("Jupyter.notebook.execute_cells([2])"))
    
    def __init__(self):
        self.indicator_selector.observe(self.indicator_selected, names='value')
        self.dimension_selector.observe(self.dimension_selected, names='index')
        self.execute_button.on_click(self.execute)
        self.output = widgets.Output()
        self.box = widgets.VBox(
            [ widgets.HBox([widgets.Label("Kennzahl: "),
                            self.indicator_selector]),
              widgets.VBox([widgets.Label('Zu exportierende Dimensionen:'),
                               self.dimension_selector]),
             
              self.filename_text,
              self.execute_button])
        display(self.box, self.output)
        
            
    def save(self):
        print("Bitte warten...")
        unidata = Unidata()
        kennzahl = unidata.create_table(self.indicator['name'])
        file = kennzahl.download_all([self.indicator['dimensions'][i] for i in self.dimensions], self.filename_text.value)
        link = FileLink(file)
        display(link, self.output)
        
output = widgets.Output()
display(widgets.HTML('<h3>Neuer Datenexport</h3>'), output)
selector = Selector()
# Out:
# HTML(value='<h3>Neuer Datenexport</h3>')
# Output()
# VBox(children=(HBox(children=(Label(value='Kennzahl: '), Dropdown(options=(('Auswählen...', -1), ('1.C.1 - Dri…
# Output()
# Bitte warten...
# Connecting to uni:data
# Creating table
# Downloading data
# Gesamt
# Agrarbiotechnologie, Lebensmittelbiotechnologie
# Andere Agrarwissenschaften
# Andere Geisteswissenschaften
# Andere Humanmedizin, Gesundheitswissenschaften
# Andere Naturwissenschaften
# Andere Sozialwissenschaften
# Andere Technische Wissenschaften
# Architektur
# Bauwesen
# Bildende Kunst
# Biologie
# Bühnengestaltung
# Chemie
# Chemische Verfahrenstechnik
# Computermusik
# Design
# Elektrotechnik, Elektronik, Informationstechnik
# Erziehungswissenschaften
# Fehlerhafte Angabe
# Film und Fernsehen
# Geowissenschaften
# Geschichte, Archäologie
# Gesundheitswissenschaften
# Humangeographie, Regionale Geographie, Raumplanung
# Industrielle Biotechnologie
# Informatik
# Interpretation - instrumental
# Interpretation - vokal
# Jazz/Improvisation
# Klinische Medizin
# Komposition
# Konservierung und Restaurierung
# Kunstwissenschaften
# Land- und Forstwirtschaft, Fischerei
# Maschinenbau
# Mathematik
# Medien- und Kommunikationswissenschaften
# Mediengestaltung
# Medizinische Biotechnologie
# Medizinisch-theoretische Wissenschaften, Pharmazie
# Medizintechnik
# Musikleitung (Dirigieren)
# Musiktherapie
# Nanotechnologie
# Nicht bekannt/nicht zuordenbar
# Pädagogik / Vermittlung
# Pädagogik / Vermittlung (2)
# Pädagogik / Vermittlung (3)
# Philosophie, Ethik, Religion
# Physik, Astronomie
# Politikwissenschaften
# Psychologie
# Rechtswissenschaften
# Schauspiel
# Soziologie
# Sprach- und Literaturwissenschaften
# Sprachkunst
# Tanz
# Theaterregie / Musiktheaterregie
# Tierzucht, Tierproduktion
# Tonmeister
# Transdisziplinäre Kunst
# Umweltbiotechnologie
# Umweltingenieurwesen, Angewandte Geowissenschaften
# Veterinärmedizin
# Werkstofftechnik
# Wirtschaftswissenschaften
# ['Gesamt', 'Universität Wien', '2018', 7801]
# ['Gesamt', 'Universität Wien', '2017', 7833]
# ['Gesamt', 'Universität Wien', '2016', 7721]
# ['Gesamt', 'Universität Graz', '2018', 3347]
# ['Gesamt', 'Universität Graz', '2017', 3126]
# ['Gesamt', 'Universität Graz', '2016', 3242]
# ['Gesamt', 'Universität Innsbruck', '2018', 4146]
# ['Gesamt', 'Universität Innsbruck', '2017', 3911]
# ['Gesamt', 'Universität Innsbruck', '2016', 3563]
# ['Gesamt', 'Medizinische Universität Wien', '2018', 3945]
# ['Gesamt', 'Medizinische Universität Wien', '2017', 3571]
# ['Gesamt', 'Medizinische Universität Wien', '2016', 3224]
# ['Gesamt', 'Medizinische Universität Graz', '2018', 2495]
# ['Gesamt', 'Medizinische Universität Graz', '2017', 2773]
# ['Gesamt', 'Medizinische Universität Graz', '2016', 2541]
# ['Gesamt', 'Medizinische Universität Innsbruck', '2018', 1402]
# ['Gesamt', 'Medizinische Universität Innsbruck', '2017', 1123]
# ['Gesamt', 'Medizinische Universität Innsbruck', '2016', 1532]
# ['Gesamt', 'Universität Salzburg', '2018', 2371]
# ['Gesamt', 'Universität Salzburg', '2017', 2669]
# ['Gesamt', 'Universität Salzburg', '2016', 3058]
# ['Gesamt', 'Technische Universität Wien', '2018', 4654]
# ['Gesamt', 'Technische Universität Wien', '2017', 4626]
# ['Gesamt', 'Technische Universität Wien', '2016', 4887]
# ['Gesamt', 'Technische Universität Graz', '2018', 2333]
# ['Gesamt', 'Technische Universität Graz', '2017', 1865]
# ['Gesamt', 'Technische Universität Graz', '2016', 2080]
# ['Gesamt', 'Montanuniversität Leoben', '2018', 964]
# ['Gesamt', 'Montanuniversität Leoben', '2017', 1041]
# ['Gesamt', 'Montanuniversität Leoben', '2016', 1039]
# ['Gesamt', 'Universität für Bodenkultur Wien', '2018', 2865]
# ['Gesamt', 'Universität für Bodenkultur Wien', '2017', 2503]
# ['Gesamt', 'Universität für Bodenkultur Wien', '2016', 2499]
# ['Gesamt', 'Veterinärmedizinische Universität Wien', '2018', 1122]
# ['Gesamt', 'Veterinärmedizinische Universität Wien', '2017', 1055]
# ['Gesamt', 'Veterinärmedizinische Universität Wien', '2016', 1141]
# ['Gesamt', 'Wirtschaftsuniversität Wien', '2018', 1560]
# ['Gesamt', 'Wirtschaftsuniversität Wien', '2017', 1507]
# ['Gesamt', 'Wirtschaftsuniversität Wien', '2016', 1212]
# ['Gesamt', 'Universität Linz', '2018', 2481]
# ['Gesamt', 'Universität Linz', '2017', 2313]
# ['Gesamt', 'Universität Linz', '2016', 2273]
# ['Gesamt', 'Universität Klagenfurt', '2018', 843]
# ['Gesamt', 'Universität Klagenfurt', '2017', 848]
# ['Gesamt', 'Universität Klagenfurt', '2016', 1041]
# ['Gesamt', 'Universität für angewandte Kunst Wien', '2018', 159]
# ['Gesamt', 'Universität für angewandte Kunst Wien', '2017', 190]
# ['Gesamt', 'Universität für angewandte Kunst Wien', '2016', 156]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2018', 210]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2017', 222]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2016', 286]
# ['Gesamt', 'Universität Mozarteum Salzburg', '2018', 389]
# ['Gesamt', 'Universität Mozarteum Salzburg', '2017', 388]
# ['Gesamt', 'Universität Mozarteum Salzburg', '2016', 381]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2018', 136]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2017', 163]
# ['Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2016', 166]
# ['Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 137]
# ['Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 128]
# ['Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 139]
# ['Gesamt', 'Akademie der bildenden Künste Wien', '2018', 127]
# ['Gesamt', 'Akademie der bildenden Künste Wien', '2017', 161]
# ['Gesamt', 'Akademie der bildenden Künste Wien', '2016', 223]
# ['Gesamt', 'Universität für Weiterbildung Krems', '2018', 450]
# ['Gesamt', 'Universität für Weiterbildung Krems', '2017', 328]
# ['Gesamt', 'Universität für Weiterbildung Krems', '2016', 503]
# ['Gesamt', 'Gesamt', '2018', 43937]
# ['Gesamt', 'Gesamt', '2017', 42344]
# ['Gesamt', 'Gesamt', '2016', 42907]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Wien', '2017', 0]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Wien', '2016', 0]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Salzburg', '2017', 2]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Salzburg', '2016', 1]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Technische Universität Wien', '2016', 1]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Technische Universität Graz', '2018', 0]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Technische Universität Graz', '2017', 2]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Montanuniversität Leoben', '2018', 1]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität für Bodenkultur Wien', '2018', 37]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität für Bodenkultur Wien', '2017', 44]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität für Bodenkultur Wien', '2016', 35]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Linz', '2018', 1]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Linz', '2017', 1]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Universität Linz', '2016', 3]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Gesamt', '2018', 39]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Gesamt', '2017', 50]
# ['Agrarbiotechnologie, Lebensmittelbiotechnologie', 'Gesamt', '2016', 41]
# ['Andere Agrarwissenschaften', 'Universität Wien', '2018', 2]
# ['Andere Agrarwissenschaften', 'Universität Wien', '2017', 1]
# ['Andere Agrarwissenschaften', 'Universität Wien', '2016', 1]
# ['Andere Agrarwissenschaften', 'Universität für Bodenkultur Wien', '2018', 226]
# ['Andere Agrarwissenschaften', 'Universität für Bodenkultur Wien', '2017', 187]
# ['Andere Agrarwissenschaften', 'Universität für Bodenkultur Wien', '2016', 196]
# ['Andere Agrarwissenschaften', 'Universität Linz', '2018', 0]
# ['Andere Agrarwissenschaften', 'Universität Klagenfurt', '2017', 9]
# ['Andere Agrarwissenschaften', 'Universität Klagenfurt', '2016', 17]
# ['Andere Agrarwissenschaften', 'Universität für Weiterbildung Krems', '2018', 0]
# ['Andere Agrarwissenschaften', 'Gesamt', '2018', 229]
# ['Andere Agrarwissenschaften', 'Gesamt', '2017', 197]
# ['Andere Agrarwissenschaften', 'Gesamt', '2016', 214]
# ['Andere Geisteswissenschaften', 'Universität Wien', '2018', 118]
# ['Andere Geisteswissenschaften', 'Universität Wien', '2017', 76]
# ['Andere Geisteswissenschaften', 'Universität Wien', '2016', 81]
# ['Andere Geisteswissenschaften', 'Medizinische Universität Graz', '2017', 1]
# ['Andere Geisteswissenschaften', 'Medizinische Universität Graz', '2016', 2]
# ['Andere Geisteswissenschaften', 'Universität Salzburg', '2018', 37]
# ['Andere Geisteswissenschaften', 'Universität Salzburg', '2017', 52]
# ['Andere Geisteswissenschaften', 'Universität Salzburg', '2016', 91]
# ['Andere Geisteswissenschaften', 'Technische Universität Wien', '2018', 6]
# ['Andere Geisteswissenschaften', 'Technische Universität Wien', '2017', 5]
# ['Andere Geisteswissenschaften', 'Technische Universität Wien', '2016', 6]
# ['Andere Geisteswissenschaften', 'Technische Universität Graz', '2018', 2]
# ['Andere Geisteswissenschaften', 'Technische Universität Graz', '2017', 2]
# ['Andere Geisteswissenschaften', 'Technische Universität Graz', '2016', 2]
# ['Andere Geisteswissenschaften', 'Universität für Bodenkultur Wien', '2018', 5]
# ['Andere Geisteswissenschaften', 'Universität für Bodenkultur Wien', '2017', 4]
# ['Andere Geisteswissenschaften', 'Universität für Bodenkultur Wien', '2016', 4]
# ['Andere Geisteswissenschaften', 'Universität Linz', '2018', 6]
# ['Andere Geisteswissenschaften', 'Universität Linz', '2017', 4]
# ['Andere Geisteswissenschaften', 'Universität Linz', '2016', 6]
# ['Andere Geisteswissenschaften', 'Universität Klagenfurt', '2018', 15]
# ['Andere Geisteswissenschaften', 'Universität Klagenfurt', '2017', 12]
# ['Andere Geisteswissenschaften', 'Universität Klagenfurt', '2016', 25]
# ['Andere Geisteswissenschaften', 'Universität für angewandte Kunst Wien', '2018', 2]
# ['Andere Geisteswissenschaften', 'Universität für angewandte Kunst Wien', '2017', 10]
# ['Andere Geisteswissenschaften', 'Universität für angewandte Kunst Wien', '2016', 12]
# ['Andere Geisteswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2018', 29]
# ['Andere Geisteswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2017', 29]
# ['Andere Geisteswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 39]
# ['Andere Geisteswissenschaften', 'Universität für Musik und darstellende Kunst Graz', '2017', 1]
# ['Andere Geisteswissenschaften', 'Universität für Musik und darstellende Kunst Graz', '2016', 1]
# ['Andere Geisteswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 5]
# ['Andere Geisteswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 3]
# ['Andere Geisteswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 5]
# ['Andere Geisteswissenschaften', 'Akademie der bildenden Künste Wien', '2018', 3]
# ['Andere Geisteswissenschaften', 'Akademie der bildenden Künste Wien', '2017', 7]
# ['Andere Geisteswissenschaften', 'Akademie der bildenden Künste Wien', '2016', 8]
# ['Andere Geisteswissenschaften', 'Universität für Weiterbildung Krems', '2018', 6]
# ['Andere Geisteswissenschaften', 'Universität für Weiterbildung Krems', '2017', 4]
# ['Andere Geisteswissenschaften', 'Universität für Weiterbildung Krems', '2016', 7]
# ['Andere Geisteswissenschaften', 'Gesamt', '2018', 233]
# ['Andere Geisteswissenschaften', 'Gesamt', '2017', 211]
# ['Andere Geisteswissenschaften', 'Gesamt', '2016', 289]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Wien', '2018', 8]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Wien', '2017', 10]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Wien', '2016', 7]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Wien', '2018', 50]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Wien', '2017', 38]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Wien', '2016', 36]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Graz', '2018', 235]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Graz', '2017', 278]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Graz', '2016', 283]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Innsbruck', '2018', 30]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Innsbruck', '2017', 24]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Medizinische Universität Innsbruck', '2016', 37]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Salzburg', '2018', 9]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Salzburg', '2017', 14]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Salzburg', '2016', 35]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Wien', '2018', 2]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Wien', '2017', 14]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Wien', '2016', 5]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Graz', '2018', 1]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Graz', '2017', 2]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Technische Universität Graz', '2016', 17]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Bodenkultur Wien', '2018', 11]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Bodenkultur Wien', '2017', 10]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Bodenkultur Wien', '2016', 10]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Linz', '2018', 37]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Linz', '2017', 25]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Linz', '2016', 9]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Klagenfurt', '2018', 3]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität Klagenfurt', '2017', 1]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Weiterbildung Krems', '2018', 5]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Weiterbildung Krems', '2017', 9]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Universität für Weiterbildung Krems', '2016', 19]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Gesamt', '2018', 391]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Gesamt', '2017', 423]
# ['Andere Humanmedizin, Gesundheitswissenschaften', 'Gesamt', '2016', 457]
# ['Andere Naturwissenschaften', 'Universität Wien', '2018', 21]
# ['Andere Naturwissenschaften', 'Universität Wien', '2017', 11]
# ['Andere Naturwissenschaften', 'Universität Wien', '2016', 22]
# ['Andere Naturwissenschaften', 'Universität Graz', '2018', 49]
# ['Andere Naturwissenschaften', 'Universität Graz', '2017', 41]
# ['Andere Naturwissenschaften', 'Universität Graz', '2016', 24]
# ['Andere Naturwissenschaften', 'Medizinische Universität Graz', '2018', 28]
# ['Andere Naturwissenschaften', 'Medizinische Universität Graz', '2017', 36]
# ['Andere Naturwissenschaften', 'Medizinische Universität Graz', '2016', 26]
# ['Andere Naturwissenschaften', 'Universität Salzburg', '2018', 8]
# ['Andere Naturwissenschaften', 'Universität Salzburg', '2017', 6]
# ['Andere Naturwissenschaften', 'Universität Salzburg', '2016', 11]
# ['Andere Naturwissenschaften', 'Technische Universität Wien', '2018', 26]
# ['Andere Naturwissenschaften', 'Technische Universität Wien', '2017', 10]
# ['Andere Naturwissenschaften', 'Technische Universität Wien', '2016', 28]
# ['Andere Naturwissenschaften', 'Technische Universität Graz', '2018', 3]
# ['Andere Naturwissenschaften', 'Technische Universität Graz', '2017', 2]
# ['Andere Naturwissenschaften', 'Technische Universität Graz', '2016', 38]
# ['Andere Naturwissenschaften', 'Montanuniversität Leoben', '2018', 1]
# ['Andere Naturwissenschaften', 'Montanuniversität Leoben', '2017', 1]
# ['Andere Naturwissenschaften', 'Universität für Bodenkultur Wien', '2018', 184]
# ['Andere Naturwissenschaften', 'Universität für Bodenkultur Wien', '2017', 171]
# ['Andere Naturwissenschaften', 'Universität für Bodenkultur Wien', '2016', 193]
# ['Andere Naturwissenschaften', 'Universität Linz', '2018', 1]
# ['Andere Naturwissenschaften', 'Universität Linz', '2017', 1]
# ['Andere Naturwissenschaften', 'Universität Linz', '2016', 1]
# ['Andere Naturwissenschaften', 'Universität Klagenfurt', '2018', 2]
# ['Andere Naturwissenschaften', 'Universität Klagenfurt', '2017', 13]
# ['Andere Naturwissenschaften', 'Universität Klagenfurt', '2016', 23]
# ['Andere Naturwissenschaften', 'Universität für angewandte Kunst Wien', '2018', 4]
# ['Andere Naturwissenschaften', 'Universität für angewandte Kunst Wien', '2017', 3]
# ['Andere Naturwissenschaften', 'Universität für angewandte Kunst Wien', '2016', 3]
# ['Andere Naturwissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 2]
# ['Andere Naturwissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 0]
# ['Andere Naturwissenschaften', 'Akademie der bildenden Künste Wien', '2018', 3]
# ['Andere Naturwissenschaften', 'Universität für Weiterbildung Krems', '2018', 4]
# ['Andere Naturwissenschaften', 'Universität für Weiterbildung Krems', '2017', 2]
# ['Andere Naturwissenschaften', 'Universität für Weiterbildung Krems', '2016', 2]
# ['Andere Naturwissenschaften', 'Gesamt', '2018', 334]
# ['Andere Naturwissenschaften', 'Gesamt', '2017', 295]
# ['Andere Naturwissenschaften', 'Gesamt', '2016', 374]
# ['Andere Sozialwissenschaften', 'Universität Wien', '2018', 64]
# ['Andere Sozialwissenschaften', 'Universität Wien', '2017', 48]
# ['Andere Sozialwissenschaften', 'Universität Wien', '2016', 67]
# ['Andere Sozialwissenschaften', 'Universität Graz', '2018', 38]
# ['Andere Sozialwissenschaften', 'Universität Graz', '2017', 21]
# ['Andere Sozialwissenschaften', 'Universität Graz', '2016', 12]
# ['Andere Sozialwissenschaften', 'Medizinische Universität Graz', '2018', 5]
# ['Andere Sozialwissenschaften', 'Medizinische Universität Graz', '2017', 4]
# ['Andere Sozialwissenschaften', 'Medizinische Universität Graz', '2016', 8]
# ['Andere Sozialwissenschaften', 'Universität Salzburg', '2018', 9]
# ['Andere Sozialwissenschaften', 'Universität Salzburg', '2017', 11]
# ['Andere Sozialwissenschaften', 'Universität Salzburg', '2016', 12]
# ['Andere Sozialwissenschaften', 'Technische Universität Wien', '2018', 10]
# ['Andere Sozialwissenschaften', 'Technische Universität Wien', '2017', 15]
# ['Andere Sozialwissenschaften', 'Technische Universität Wien', '2016', 18]
# ['Andere Sozialwissenschaften', 'Technische Universität Graz', '2018', 7]
# ['Andere Sozialwissenschaften', 'Technische Universität Graz', '2017', 6]
# ['Andere Sozialwissenschaften', 'Technische Universität Graz', '2016', 9]
# ['Andere Sozialwissenschaften', 'Montanuniversität Leoben', '2017', 1]
# ['Andere Sozialwissenschaften', 'Universität für Bodenkultur Wien', '2018', 69]
# ['Andere Sozialwissenschaften', 'Universität für Bodenkultur Wien', '2017', 53]
# ['Andere Sozialwissenschaften', 'Universität für Bodenkultur Wien', '2016', 55]
# ['Andere Sozialwissenschaften', 'Wirtschaftsuniversität Wien', '2018', 4]
# ['Andere Sozialwissenschaften', 'Wirtschaftsuniversität Wien', '2017', 42]
# ['Andere Sozialwissenschaften', 'Wirtschaftsuniversität Wien', '2016', 29]
# ['Andere Sozialwissenschaften', 'Universität Linz', '2018', 41]
# ['Andere Sozialwissenschaften', 'Universität Linz', '2017', 52]
# ['Andere Sozialwissenschaften', 'Universität Linz', '2016', 61]
# ['Andere Sozialwissenschaften', 'Universität Klagenfurt', '2018', 12]
# ['Andere Sozialwissenschaften', 'Universität Klagenfurt', '2017', 14]
# ['Andere Sozialwissenschaften', 'Universität Klagenfurt', '2016', 32]
# ['Andere Sozialwissenschaften', 'Universität für angewandte Kunst Wien', '2018', 4]
# ['Andere Sozialwissenschaften', 'Universität für angewandte Kunst Wien', '2017', 1]
# ['Andere Sozialwissenschaften', 'Universität für angewandte Kunst Wien', '2016', 0]
# ['Andere Sozialwissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2018', 6]
# ['Andere Sozialwissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2017', 3]
# ['Andere Sozialwissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 3]
# ['Andere Sozialwissenschaften', 'Universität Mozarteum Salzburg', '2018', 10]
# ['Andere Sozialwissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 0]
# ['Andere Sozialwissenschaften', 'Akademie der bildenden Künste Wien', '2016', 2]
# ['Andere Sozialwissenschaften', 'Universität für Weiterbildung Krems', '2018', 27]
# ['Andere Sozialwissenschaften', 'Universität für Weiterbildung Krems', '2017', 44]
# ['Andere Sozialwissenschaften', 'Universität für Weiterbildung Krems', '2016', 38]
# ['Andere Sozialwissenschaften', 'Gesamt', '2018', 305]
# ['Andere Sozialwissenschaften', 'Gesamt', '2017', 314]
# ['Andere Sozialwissenschaften', 'Gesamt', '2016', 345]
# ['Andere Technische Wissenschaften', 'Universität Wien', '2018', 3]
# ['Andere Technische Wissenschaften', 'Universität Wien', '2017', 3]
# ['Andere Technische Wissenschaften', 'Universität Wien', '2016', 1]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Wien', '2018', 1]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Wien', '2017', 0]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Graz', '2018', 2]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Graz', '2017', 2]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Graz', '2016', 2]
# ['Andere Technische Wissenschaften', 'Medizinische Universität Innsbruck', '2016', 2]
# ['Andere Technische Wissenschaften', 'Universität Salzburg', '2018', 2]
# ['Andere Technische Wissenschaften', 'Universität Salzburg', '2017', 1]
# ['Andere Technische Wissenschaften', 'Universität Salzburg', '2016', 17]
# ['Andere Technische Wissenschaften', 'Technische Universität Wien', '2018', 79]
# ['Andere Technische Wissenschaften', 'Technische Universität Wien', '2017', 86]
# ['Andere Technische Wissenschaften', 'Technische Universität Wien', '2016', 112]
# ['Andere Technische Wissenschaften', 'Technische Universität Graz', '2018', 40]
# ['Andere Technische Wissenschaften', 'Technische Universität Graz', '2017', 29]
# ['Andere Technische Wissenschaften', 'Technische Universität Graz', '2016', 54]
# ['Andere Technische Wissenschaften', 'Montanuniversität Leoben', '2018', 183]
# ['Andere Technische Wissenschaften', 'Montanuniversität Leoben', '2017', 208]
# ['Andere Technische Wissenschaften', 'Montanuniversität Leoben', '2016', 214]
# ['Andere Technische Wissenschaften', 'Universität für Bodenkultur Wien', '2018', 133]
# ['Andere Technische Wissenschaften', 'Universität für Bodenkultur Wien', '2017', 113]
# ['Andere Technische Wissenschaften', 'Universität für Bodenkultur Wien', '2016', 125]
# ['Andere Technische Wissenschaften', 'Universität Linz', '2018', 18]
# ['Andere Technische Wissenschaften', 'Universität Linz', '2017', 16]
# ['Andere Technische Wissenschaften', 'Universität Linz', '2016', 13]
# ['Andere Technische Wissenschaften', 'Universität Klagenfurt', '2018', 5]
# ['Andere Technische Wissenschaften', 'Universität Klagenfurt', '2017', 4]
# ['Andere Technische Wissenschaften', 'Universität Klagenfurt', '2016', 3]
# ['Andere Technische Wissenschaften', 'Universität für angewandte Kunst Wien', '2017', 0]
# ['Andere Technische Wissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2017', 0]
# ['Andere Technische Wissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 1]
# ['Andere Technische Wissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 2]
# ['Andere Technische Wissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 3]
# ['Andere Technische Wissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 1]
# ['Andere Technische Wissenschaften', 'Akademie der bildenden Künste Wien', '2017', 1]
# ['Andere Technische Wissenschaften', 'Universität für Weiterbildung Krems', '2018', 0]
# ['Andere Technische Wissenschaften', 'Universität für Weiterbildung Krems', '2016', 1]
# ['Andere Technische Wissenschaften', 'Gesamt', '2018', 468]
# ['Andere Technische Wissenschaften', 'Gesamt', '2017', 467]
# ['Andere Technische Wissenschaften', 'Gesamt', '2016', 544]
# ['Architektur', 'Technische Universität Wien', '2018', 42]
# ['Architektur', 'Technische Universität Wien', '2017', 36]
# ['Architektur', 'Technische Universität Wien', '2016', 28]
# ['Architektur', 'Universität für angewandte Kunst Wien', '2018', 6]
# ['Architektur', 'Universität für angewandte Kunst Wien', '2017', 12]
# ['Architektur', 'Universität für angewandte Kunst Wien', '2016', 11]
# ['Architektur', 'Universität Mozarteum Salzburg', '2017', 1]
# ['Architektur', 'Universität Mozarteum Salzburg', '2016', 1]
# ['Architektur', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 13]
# ['Architektur', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 8]
# ['Architektur', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 18]
# ['Architektur', 'Akademie der bildenden Künste Wien', '2018', 3]
# ['Architektur', 'Akademie der bildenden Künste Wien', '2017', 3]
# ['Architektur', 'Akademie der bildenden Künste Wien', '2016', 6]
# ['Architektur', 'Universität für Weiterbildung Krems', '2018', 3]
# ['Architektur', 'Universität für Weiterbildung Krems', '2017', 2]
# ['Architektur', 'Universität für Weiterbildung Krems', '2016', 7]
# ['Architektur', 'Gesamt', '2018', 66]
# ['Architektur', 'Gesamt', '2017', 61]
# ['Architektur', 'Gesamt', '2016', 70]
# ['Bauwesen', 'Universität Wien', '2018', 1]
# ['Bauwesen', 'Universität Wien', '2017', 4]
# ['Bauwesen', 'Universität Wien', '2016', 2]
# ['Bauwesen', 'Universität Innsbruck', '2018', 241]
# ['Bauwesen', 'Universität Innsbruck', '2017', 278]
# ['Bauwesen', 'Universität Innsbruck', '2016', 171]
# ['Bauwesen', 'Universität Salzburg', '2018', 2]
# ['Bauwesen', 'Universität Salzburg', '2017', 1]
# ['Bauwesen', 'Universität Salzburg', '2016', 2]
# ['Bauwesen', 'Technische Universität Wien', '2018', 544]
# ['Bauwesen', 'Technische Universität Wien', '2017', 572]
# ['Bauwesen', 'Technische Universität Wien', '2016', 606]
# ['Bauwesen', 'Technische Universität Graz', '2018', 245]
# ['Bauwesen', 'Technische Universität Graz', '2017', 185]
# ['Bauwesen', 'Technische Universität Graz', '2016', 238]
# ['Bauwesen', 'Montanuniversität Leoben', '2018', 2]
# ['Bauwesen', 'Montanuniversität Leoben', '2017', 4]
# ['Bauwesen', 'Montanuniversität Leoben', '2016', 7]
# ['Bauwesen', 'Universität für Bodenkultur Wien', '2018', 145]
# ['Bauwesen', 'Universität für Bodenkultur Wien', '2017', 117]
# ['Bauwesen', 'Universität für Bodenkultur Wien', '2016', 116]
# ['Bauwesen', 'Universität Linz', '2018', 7]
# ['Bauwesen', 'Universität Linz', '2017', 10]
# ['Bauwesen', 'Universität Linz', '2016', 11]
# ['Bauwesen', 'Universität Klagenfurt', '2018', 2]
# ['Bauwesen', 'Universität Klagenfurt', '2017', 3]
# ['Bauwesen', 'Universität Klagenfurt', '2016', 1]
# ['Bauwesen', 'Akademie der bildenden Künste Wien', '2018', 6]
# ['Bauwesen', 'Akademie der bildenden Künste Wien', '2017', 11]
# ['Bauwesen', 'Akademie der bildenden Künste Wien', '2016', 24]
# ['Bauwesen', 'Universität für Weiterbildung Krems', '2018', 3]
# ['Bauwesen', 'Universität für Weiterbildung Krems', '2017', 2]
# ['Bauwesen', 'Universität für Weiterbildung Krems', '2016', 6]
# ['Bauwesen', 'Gesamt', '2018', 1197]
# ['Bauwesen', 'Gesamt', '2017', 1185]
# ['Bauwesen', 'Gesamt', '2016', 1183]
# ['Bildende Kunst', 'Technische Universität Wien', '2018', 1]
# ['Bildende Kunst', 'Technische Universität Wien', '2017', 3]
# ['Bildende Kunst', 'Technische Universität Wien', '2016', 1]
# ['Bildende Kunst', 'Universität für angewandte Kunst Wien', '2018', 17]
# ['Bildende Kunst', 'Universität für angewandte Kunst Wien', '2017', 17]
# ['Bildende Kunst', 'Universität für angewandte Kunst Wien', '2016', 24]
# ['Bildende Kunst', 'Universität Mozarteum Salzburg', '2018', 13]
# ['Bildende Kunst', 'Universität Mozarteum Salzburg', '2017', 14]
# ['Bildende Kunst', 'Universität Mozarteum Salzburg', '2016', 4]
# ['Bildende Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 2]
# ['Bildende Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 4]
# ['Bildende Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 2]
# ['Bildende Kunst', 'Akademie der bildenden Künste Wien', '2018', 24]
# ['Bildende Kunst', 'Akademie der bildenden Künste Wien', '2017', 24]
# ['Bildende Kunst', 'Akademie der bildenden Künste Wien', '2016', 30]
# ['Bildende Kunst', 'Universität für Weiterbildung Krems', '2018', 3]
# ['Bildende Kunst', 'Universität für Weiterbildung Krems', '2017', 14]
# ['Bildende Kunst', 'Universität für Weiterbildung Krems', '2016', 6]
# ['Bildende Kunst', 'Gesamt', '2018', 59]
# ['Bildende Kunst', 'Gesamt', '2017', 75]
# ['Bildende Kunst', 'Gesamt', '2016', 68]
# ['Biologie', 'Universität Wien', '2018', 769]
# ['Biologie', 'Universität Wien', '2017', 653]
# ['Biologie', 'Universität Wien', '2016', 789]
# ['Biologie', 'Universität Graz', '2018', 282]
# ['Biologie', 'Universität Graz', '2017', 248]
# ['Biologie', 'Universität Graz', '2016', 289]
# ['Biologie', 'Universität Innsbruck', '2018', 305]
# ['Biologie', 'Universität Innsbruck', '2017', 274]
# ['Biologie', 'Universität Innsbruck', '2016', 291]
# ['Biologie', 'Medizinische Universität Wien', '2018', 100]
# ['Biologie', 'Medizinische Universität Wien', '2017', 99]
# ['Biologie', 'Medizinische Universität Wien', '2016', 97]
# ['Biologie', 'Medizinische Universität Graz', '2018', 101]
# ['Biologie', 'Medizinische Universität Graz', '2017', 109]
# ['Biologie', 'Medizinische Universität Graz', '2016', 95]
# ['Biologie', 'Medizinische Universität Innsbruck', '2018', 52]
# ['Biologie', 'Medizinische Universität Innsbruck', '2017', 46]
# ['Biologie', 'Medizinische Universität Innsbruck', '2016', 22]
# ['Biologie', 'Universität Salzburg', '2018', 122]
# ['Biologie', 'Universität Salzburg', '2017', 174]
# ['Biologie', 'Universität Salzburg', '2016', 166]
# ['Biologie', 'Technische Universität Wien', '2018', 23]
# ['Biologie', 'Technische Universität Wien', '2017', 19]
# ['Biologie', 'Technische Universität Wien', '2016', 15]
# ['Biologie', 'Technische Universität Graz', '2018', 75]
# ['Biologie', 'Technische Universität Graz', '2017', 52]
# ['Biologie', 'Technische Universität Graz', '2016', 31]
# ['Biologie', 'Montanuniversität Leoben', '2018', 1]
# ['Biologie', 'Montanuniversität Leoben', '2017', 0]
# ['Biologie', 'Universität für Bodenkultur Wien', '2018', 425]
# ['Biologie', 'Universität für Bodenkultur Wien', '2017', 351]
# ['Biologie', 'Universität für Bodenkultur Wien', '2016', 414]
# ['Biologie', 'Veterinärmedizinische Universität Wien', '2018', 193]
# ['Biologie', 'Veterinärmedizinische Universität Wien', '2017', 220]
# ['Biologie', 'Veterinärmedizinische Universität Wien', '2016', 216]
# ['Biologie', 'Universität Linz', '2018', 22]
# ['Biologie', 'Universität Linz', '2017', 26]
# ['Biologie', 'Universität Linz', '2016', 29]
# ['Biologie', 'Universität Klagenfurt', '2018', 1]
# ['Biologie', 'Universität Klagenfurt', '2017', 0]
# ['Biologie', 'Universität Klagenfurt', '2016', 1]
# ['Biologie', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 1]
# ['Biologie', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 1]
# ['Biologie', 'Universität für Weiterbildung Krems', '2018', 10]
# ['Biologie', 'Universität für Weiterbildung Krems', '2017', 8]
# ['Biologie', 'Universität für Weiterbildung Krems', '2016', 13]
# ['Biologie', 'Gesamt', '2018', 2480]
# ['Biologie', 'Gesamt', '2017', 2280]
# ['Biologie', 'Gesamt', '2016', 2470]
# ['Bühnengestaltung', 'Universität für Musik und darstellende Kunst Wien', '2016', 2]
# ['Bühnengestaltung', 'Universität Mozarteum Salzburg', '2018', 132]
# ['Bühnengestaltung', 'Universität Mozarteum Salzburg', '2017', 113]
# ['Bühnengestaltung', 'Universität Mozarteum Salzburg', '2016', 131]
# ['Bühnengestaltung', 'Gesamt', '2018', 132]
# ['Bühnengestaltung', 'Gesamt', '2017', 113]
# ['Bühnengestaltung', 'Gesamt', '2016', 133]
# ['Chemie', 'Universität Wien', '2018', 322]
# ['Chemie', 'Universität Wien', '2017', 369]
# ['Chemie', 'Universität Wien', '2016', 364]
# ['Chemie', 'Universität Graz', '2018', 128]
# ['Chemie', 'Universität Graz', '2017', 121]
# ['Chemie', 'Universität Graz', '2016', 125]
# ['Chemie', 'Universität Innsbruck', '2018', 149]
# ['Chemie', 'Universität Innsbruck', '2017', 182]
# ['Chemie', 'Universität Innsbruck', '2016', 174]
# ['Chemie', 'Medizinische Universität Wien', '2018', 8]
# ['Chemie', 'Medizinische Universität Wien', '2017', 2]
# ['Chemie', 'Medizinische Universität Wien', '2016', 1]
# ['Chemie', 'Medizinische Universität Graz', '2018', 18]
# ['Chemie', 'Medizinische Universität Graz', '2017', 25]
# ['Chemie', 'Medizinische Universität Graz', '2016', 21]
# ['Chemie', 'Medizinische Universität Innsbruck', '2018', 1]
# ['Chemie', 'Medizinische Universität Innsbruck', '2017', 0]
# ['Chemie', 'Medizinische Universität Innsbruck', '2016', 1]
# ['Chemie', 'Universität Salzburg', '2018', 37]
# ['Chemie', 'Universität Salzburg', '2017', 61]
# ['Chemie', 'Universität Salzburg', '2016', 72]
# ['Chemie', 'Technische Universität Wien', '2018', 411]
# ['Chemie', 'Technische Universität Wien', '2017', 413]
# ['Chemie', 'Technische Universität Wien', '2016', 424]
# ['Chemie', 'Technische Universität Graz', '2018', 187]
# ['Chemie', 'Technische Universität Graz', '2017', 168]
# ['Chemie', 'Technische Universität Graz', '2016', 167]
# ['Chemie', 'Montanuniversität Leoben', '2018', 61]
# ['Chemie', 'Montanuniversität Leoben', '2017', 39]
# ['Chemie', 'Montanuniversität Leoben', '2016', 47]
# ['Chemie', 'Universität für Bodenkultur Wien', '2018', 267]
# ['Chemie', 'Universität für Bodenkultur Wien', '2017', 291]
# ['Chemie', 'Universität für Bodenkultur Wien', '2016', 254]
# ['Chemie', 'Universität Linz', '2018', 58]
# ['Chemie', 'Universität Linz', '2017', 77]
# ['Chemie', 'Universität Linz', '2016', 69]
# ['Chemie', 'Universität Klagenfurt', '2017', 0]
# ['Chemie', 'Universität Klagenfurt', '2016', 0]
# ['Chemie', 'Akademie der bildenden Künste Wien', '2018', 8]
# ['Chemie', 'Akademie der bildenden Künste Wien', '2017', 5]
# ['Chemie', 'Akademie der bildenden Künste Wien', '2016', 2]
# ['Chemie', 'Universität für Weiterbildung Krems', '2018', 0]
# ['Chemie', 'Universität für Weiterbildung Krems', '2017', 0]
# ['Chemie', 'Universität für Weiterbildung Krems', '2016', 1]
# ['Chemie', 'Gesamt', '2018', 1655]
# ['Chemie', 'Gesamt', '2017', 1752]
# ['Chemie', 'Gesamt', '2016', 1721]
# ['Chemische Verfahrenstechnik', 'Universität Wien', '2017', 1]
# ['Chemische Verfahrenstechnik', 'Medizinische Universität Graz', '2017', 0]
# ['Chemische Verfahrenstechnik', 'Medizinische Universität Graz', '2016', 0]
# ['Chemische Verfahrenstechnik', 'Universität Salzburg', '2016', 1]
# ['Chemische Verfahrenstechnik', 'Technische Universität Wien', '2018', 349]
# ['Chemische Verfahrenstechnik', 'Technische Universität Wien', '2017', 406]
# ['Chemische Verfahrenstechnik', 'Technische Universität Wien', '2016', 416]
# ['Chemische Verfahrenstechnik', 'Technische Universität Graz', '2018', 63]
# ['Chemische Verfahrenstechnik', 'Technische Universität Graz', '2017', 53]
# ['Chemische Verfahrenstechnik', 'Technische Universität Graz', '2016', 69]
# ['Chemische Verfahrenstechnik', 'Montanuniversität Leoben', '2018', 8]
# ['Chemische Verfahrenstechnik', 'Montanuniversität Leoben', '2017', 17]
# ['Chemische Verfahrenstechnik', 'Montanuniversität Leoben', '2016', 13]
# ['Chemische Verfahrenstechnik', 'Universität für Bodenkultur Wien', '2018', 15]
# ['Chemische Verfahrenstechnik', 'Universität für Bodenkultur Wien', '2017', 10]
# ['Chemische Verfahrenstechnik', 'Universität für Bodenkultur Wien', '2016', 8]
# ['Chemische Verfahrenstechnik', 'Universität Linz', '2018', 6]
# ['Chemische Verfahrenstechnik', 'Universität Linz', '2017', 20]
# ['Chemische Verfahrenstechnik', 'Universität Linz', '2016', 17]
# ['Chemische Verfahrenstechnik', 'Universität für angewandte Kunst Wien', '2018', 1]
# ['Chemische Verfahrenstechnik', 'Universität für angewandte Kunst Wien', '2017', 1]
# ['Chemische Verfahrenstechnik', 'Universität für angewandte Kunst Wien', '2016', 2]
# ['Chemische Verfahrenstechnik', 'Universität für Weiterbildung Krems', '2018', 1]
# ['Chemische Verfahrenstechnik', 'Gesamt', '2018', 442]
# ['Chemische Verfahrenstechnik', 'Gesamt', '2017', 507]
# ['Chemische Verfahrenstechnik', 'Gesamt', '2016', 526]
# ['Computermusik', 'Universität für angewandte Kunst Wien', '2016', 0]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Wien', '2018', 5]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Wien', '2017', 2]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Wien', '2016', 3]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Graz', '2018', 8]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Graz', '2017', 13]
# ['Computermusik', 'Universität für Musik und darstellende Kunst Graz', '2016', 7]
# ['Computermusik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 4]
# ['Computermusik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 1]
# ['Computermusik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 2]
# ['Computermusik', 'Gesamt', '2018', 17]
# ['Computermusik', 'Gesamt', '2017', 16]
# ['Computermusik', 'Gesamt', '2016', 12]
# ['Design', 'Technische Universität Wien', '2018', 2]
# ['Design', 'Technische Universität Wien', '2017', 2]
# ['Design', 'Technische Universität Wien', '2016', 7]
# ['Design', 'Universität für angewandte Kunst Wien', '2018', 5]
# ['Design', 'Universität für angewandte Kunst Wien', '2017', 12]
# ['Design', 'Universität für angewandte Kunst Wien', '2016', 6]
# ['Design', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 5]
# ['Design', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 2]
# ['Design', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 4]
# ['Design', 'Akademie der bildenden Künste Wien', '2018', 1]
# ['Design', 'Akademie der bildenden Künste Wien', '2017', 1]
# ['Design', 'Universität für Weiterbildung Krems', '2017', 10]
# ['Design', 'Universität für Weiterbildung Krems', '2016', 0]
# ['Design', 'Gesamt', '2018', 12]
# ['Design', 'Gesamt', '2017', 26]
# ['Design', 'Gesamt', '2016', 18]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Wien', '2018', 12]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Wien', '2017', 15]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Wien', '2016', 14]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Innsbruck', '2018', 28]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Innsbruck', '2017', 9]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Innsbruck', '2016', 20]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Wien', '2018', 2]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Wien', '2017', 2]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Wien', '2016', 1]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Graz', '2018', 5]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Graz', '2017', 5]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Medizinische Universität Graz', '2016', 7]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Salzburg', '2018', 0]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Salzburg', '2017', 1]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Wien', '2018', 682]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Wien', '2017', 729]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Wien', '2016', 821]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Graz', '2018', 325]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Graz', '2017', 243]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Technische Universität Graz', '2016', 219]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Montanuniversität Leoben', '2018', 14]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Montanuniversität Leoben', '2017', 7]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Montanuniversität Leoben', '2016', 9]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Bodenkultur Wien', '2018', 4]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Bodenkultur Wien', '2017', 2]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Bodenkultur Wien', '2016', 2]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Linz', '2018', 206]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Linz', '2017', 199]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Linz', '2016', 182]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Klagenfurt', '2018', 43]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Klagenfurt', '2017', 72]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität Klagenfurt', '2016', 73]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Musik und darstellende Kunst Graz', '2018', 5]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Musik und darstellende Kunst Graz', '2017', 4]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Musik und darstellende Kunst Graz', '2016', 4]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 1]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 0]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 5]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Weiterbildung Krems', '2018', 31]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Weiterbildung Krems', '2017', 26]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Universität für Weiterbildung Krems', '2016', 65]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Gesamt', '2018', 1356]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Gesamt', '2017', 1313]
# ['Elektrotechnik, Elektronik, Informationstechnik', 'Gesamt', '2016', 1422]
# ['Erziehungswissenschaften', 'Universität Wien', '2018', 314]
# ['Erziehungswissenschaften', 'Universität Wien', '2017', 267]
# ['Erziehungswissenschaften', 'Universität Wien', '2016', 259]
# ['Erziehungswissenschaften', 'Universität Graz', '2018', 168]
# ['Erziehungswissenschaften', 'Universität Graz', '2017', 178]
# ['Erziehungswissenschaften', 'Universität Graz', '2016', 266]
# ['Erziehungswissenschaften', 'Universität Innsbruck', '2018', 225]
# ['Erziehungswissenschaften', 'Universität Innsbruck', '2017', 245]
# ['Erziehungswissenschaften', 'Universität Innsbruck', '2016', 167]
# ['Erziehungswissenschaften', 'Medizinische Universität Wien', '2018', 27]
# ['Erziehungswissenschaften', 'Medizinische Universität Wien', '2017', 14]
# ['Erziehungswissenschaften', 'Medizinische Universität Wien', '2016', 15]
# ['Erziehungswissenschaften', 'Medizinische Universität Graz', '2018', 1]
# ['Erziehungswissenschaften', 'Medizinische Universität Graz', '2017', 3]
# ['Erziehungswissenschaften', 'Medizinische Universität Graz', '2016', 1]
# ['Erziehungswissenschaften', 'Universität Salzburg', '2018', 137]
# ['Erziehungswissenschaften', 'Universität Salzburg', '2017', 103]
# ['Erziehungswissenschaften', 'Universität Salzburg', '2016', 148]
# ['Erziehungswissenschaften', 'Technische Universität Graz', '2018', 48]
# ['Erziehungswissenschaften', 'Technische Universität Graz', '2017', 53]
# ['Erziehungswissenschaften', 'Technische Universität Graz', '2016', 66]
# ['Erziehungswissenschaften', 'Montanuniversität Leoben', '2017', 1]
# ['Erziehungswissenschaften', 'Universität für Bodenkultur Wien', '2018', 2]
# ['Erziehungswissenschaften', 'Universität für Bodenkultur Wien', '2017', 3]
# ['Erziehungswissenschaften', 'Universität für Bodenkultur Wien', '2016', 4]
# ['Erziehungswissenschaften', 'Universität Linz', '2018', 105]
# ['Erziehungswissenschaften', 'Universität Linz', '2017', 61]
# ['Erziehungswissenschaften', 'Universität Linz', '2016', 50]
# ['Erziehungswissenschaften', 'Universität Klagenfurt', '2018', 96]
# ['Erziehungswissenschaften', 'Universität Klagenfurt', '2017', 71]
# ['Erziehungswissenschaften', 'Universität Klagenfurt', '2016', 102]
# ['Erziehungswissenschaften', 'Universität für angewandte Kunst Wien', '2018', 6]
# ['Erziehungswissenschaften', 'Universität für angewandte Kunst Wien', '2017', 6]
# ['Erziehungswissenschaften', 'Universität für angewandte Kunst Wien', '2016', 7]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2018', 0]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2017', 1]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 1]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Graz', '2018', 3]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Graz', '2017', 0]
# ['Erziehungswissenschaften', 'Universität für Musik und darstellende Kunst Graz', '2016', 1]
# ['Erziehungswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 1]
# ['Erziehungswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 5]
# ['Erziehungswissenschaften', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 6]
# ['Erziehungswissenschaften', 'Akademie der bildenden Künste Wien', '2017', 4]
# ['Erziehungswissenschaften', 'Akademie der bildenden Künste Wien', '2016', 9]
# ['Erziehungswissenschaften', 'Universität für Weiterbildung Krems', '2018', 7]
# ['Erziehungswissenschaften', 'Universität für Weiterbildung Krems', '2017', 7]
# ['Erziehungswissenschaften', 'Universität für Weiterbildung Krems', '2016', 14]
# ['Erziehungswissenschaften', 'Gesamt', '2018', 1140]
# ['Erziehungswissenschaften', 'Gesamt', '2017', 1020]
# ['Erziehungswissenschaften', 'Gesamt', '2016', 1116]
# ['Film und Fernsehen', 'Universität für angewandte Kunst Wien', '2016', 0]
# ['Film und Fernsehen', 'Universität für Musik und darstellende Kunst Wien', '2018', 1]
# ['Film und Fernsehen', 'Universität für Musik und darstellende Kunst Wien', '2017', 1]
# ['Film und Fernsehen', 'Universität für Musik und darstellende Kunst Wien', '2016', 1]
# ['Film und Fernsehen', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 1]
# ['Film und Fernsehen', 'Akademie der bildenden Künste Wien', '2018', 10]
# ['Film und Fernsehen', 'Akademie der bildenden Künste Wien', '2017', 3]
# ['Film und Fernsehen', 'Gesamt', '2018', 12]
# ['Film und Fernsehen', 'Gesamt', '2017', 3]
# ['Film und Fernsehen', 'Gesamt', '2016', 2]
# ['Geowissenschaften', 'Universität Wien', '2018', 364]
# ['Geowissenschaften', 'Universität Wien', '2017', 363]
# ['Geowissenschaften', 'Universität Wien', '2016', 341]
# ['Geowissenschaften', 'Universität Graz', '2018', 154]
# ['Geowissenschaften', 'Universität Graz', '2017', 149]
# ['Geowissenschaften', 'Universität Graz', '2016', 191]
# ['Geowissenschaften', 'Universität Innsbruck', '2018', 212]
# ['Geowissenschaften', 'Universität Innsbruck', '2017', 234]
# ['Geowissenschaften', 'Universität Innsbruck', '2016', 236]
# ['Geowissenschaften', 'Medizinische Universität Innsbruck', '2016', 2]
# ['Geowissenschaften', 'Universität Salzburg', '2018', 166]
# ['Geowissenschaften', 'Universität Salzburg', '2017', 148]
# ['Geowissenschaften', 'Universität Salzburg', '2016', 175]
# ...
# ['Sprach- und Literaturwissenschaften', 'Akademie der bildenden Künste Wien', '2017', 2]
# ['Sprach- und Literaturwissenschaften', 'Akademie der bildenden Künste Wien', '2016', 2]
# ['Sprach- und Literaturwissenschaften', 'Universität für Weiterbildung Krems', '2018', 7]
# ['Sprach- und Literaturwissenschaften', 'Universität für Weiterbildung Krems', '2017', 6]
# ['Sprach- und Literaturwissenschaften', 'Universität für Weiterbildung Krems', '2016', 10]
# ['Sprach- und Literaturwissenschaften', 'Gesamt', '2018', 1903]
# ['Sprach- und Literaturwissenschaften', 'Gesamt', '2017', 1883]
# ['Sprach- und Literaturwissenschaften', 'Gesamt', '2016', 1820]
# ['Sprachkunst', 'Technische Universität Wien', '2018', 0]
# ['Sprachkunst', 'Technische Universität Wien', '2017', 1]
# ['Sprachkunst', 'Technische Universität Wien', '2016', 0]
# ['Sprachkunst', 'Universität für angewandte Kunst Wien', '2018', 6]
# ['Sprachkunst', 'Universität für angewandte Kunst Wien', '2017', 9]
# ['Sprachkunst', 'Universität für angewandte Kunst Wien', '2016', 10]
# ['Sprachkunst', 'Universität für Weiterbildung Krems', '2017', 1]
# ['Sprachkunst', 'Gesamt', '2018', 6]
# ['Sprachkunst', 'Gesamt', '2017', 11]
# ['Sprachkunst', 'Gesamt', '2016', 10]
# ['Tanz', 'Universität für angewandte Kunst Wien', '2017', 2]
# ['Tanz', 'Universität für Musik und darstellende Kunst Wien', '2017', 0]
# ['Tanz', 'Universität Mozarteum Salzburg', '2016', 0]
# ['Tanz', 'Universität für Musik und darstellende Kunst Graz', '2017', 0]
# ['Tanz', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 0]
# ['Tanz', 'Akademie der bildenden Künste Wien', '2018', 2]
# ['Tanz', 'Akademie der bildenden Künste Wien', '2017', 2]
# ['Tanz', 'Akademie der bildenden Künste Wien', '2016', 2]
# ['Tanz', 'Gesamt', '2018', 2]
# ['Tanz', 'Gesamt', '2017', 4]
# ['Tanz', 'Gesamt', '2016', 2]
# ['Theaterregie / Musiktheaterregie', 'Universität Mozarteum Salzburg', '2018', 3]
# ['Theaterregie / Musiktheaterregie', 'Universität Mozarteum Salzburg', '2017', 2]
# ['Theaterregie / Musiktheaterregie', 'Universität für Weiterbildung Krems', '2017', 0]
# ['Theaterregie / Musiktheaterregie', 'Gesamt', '2018', 3]
# ['Theaterregie / Musiktheaterregie', 'Gesamt', '2017', 2]
# ['Tierzucht, Tierproduktion', 'Universität Wien', '2018', 1]
# ['Tierzucht, Tierproduktion', 'Universität Wien', '2017', 0]
# ['Tierzucht, Tierproduktion', 'Universität Wien', '2016', 2]
# ['Tierzucht, Tierproduktion', 'Medizinische Universität Wien', '2018', 3]
# ['Tierzucht, Tierproduktion', 'Medizinische Universität Wien', '2017', 3]
# ['Tierzucht, Tierproduktion', 'Medizinische Universität Wien', '2016', 1]
# ['Tierzucht, Tierproduktion', 'Technische Universität Graz', '2017', 1]
# ['Tierzucht, Tierproduktion', 'Universität für Bodenkultur Wien', '2018', 87]
# ['Tierzucht, Tierproduktion', 'Universität für Bodenkultur Wien', '2017', 78]
# ['Tierzucht, Tierproduktion', 'Universität für Bodenkultur Wien', '2016', 84]
# ['Tierzucht, Tierproduktion', 'Universität Linz', '2018', 1]
# ['Tierzucht, Tierproduktion', 'Universität Linz', '2017', 1]
# ['Tierzucht, Tierproduktion', 'Universität Linz', '2016', 3]
# ['Tierzucht, Tierproduktion', 'Gesamt', '2018', 92]
# ['Tierzucht, Tierproduktion', 'Gesamt', '2017', 84]
# ['Tierzucht, Tierproduktion', 'Gesamt', '2016', 91]
# ['Tonmeister', 'Universität für Musik und darstellende Kunst Wien', '2018', 5]
# ['Tonmeister', 'Universität für Musik und darstellende Kunst Wien', '2017', 1]
# ['Tonmeister', 'Universität Mozarteum Salzburg', '2018', 1]
# ['Tonmeister', 'Universität Mozarteum Salzburg', '2017', 1]
# ['Tonmeister', 'Universität Mozarteum Salzburg', '2016', 1]
# ['Tonmeister', 'Gesamt', '2018', 5]
# ['Tonmeister', 'Gesamt', '2017', 2]
# ['Tonmeister', 'Gesamt', '2016', 1]
# ['Transdisziplinäre Kunst', 'Technische Universität Wien', '2018', 10]
# ['Transdisziplinäre Kunst', 'Technische Universität Wien', '2017', 4]
# ['Transdisziplinäre Kunst', 'Technische Universität Wien', '2016', 10]
# ['Transdisziplinäre Kunst', 'Universität für angewandte Kunst Wien', '2018', 3]
# ['Transdisziplinäre Kunst', 'Universität für angewandte Kunst Wien', '2017', 5]
# ['Transdisziplinäre Kunst', 'Universität für angewandte Kunst Wien', '2016', 3]
# ['Transdisziplinäre Kunst', 'Universität für Musik und darstellende Kunst Wien', '2018', 0]
# ['Transdisziplinäre Kunst', 'Universität für Musik und darstellende Kunst Wien', '2017', 0]
# ['Transdisziplinäre Kunst', 'Universität für Musik und darstellende Kunst Wien', '2016', 0]
# ['Transdisziplinäre Kunst', 'Universität Mozarteum Salzburg', '2018', 4]
# ['Transdisziplinäre Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 2]
# ['Transdisziplinäre Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 2]
# ['Transdisziplinäre Kunst', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 3]
# ['Transdisziplinäre Kunst', 'Akademie der bildenden Künste Wien', '2018', 3]
# ['Transdisziplinäre Kunst', 'Akademie der bildenden Künste Wien', '2017', 3]
# ['Transdisziplinäre Kunst', 'Akademie der bildenden Künste Wien', '2016', 6]
# ['Transdisziplinäre Kunst', 'Universität für Weiterbildung Krems', '2018', 5]
# ['Transdisziplinäre Kunst', 'Universität für Weiterbildung Krems', '2017', 2]
# ['Transdisziplinäre Kunst', 'Gesamt', '2018', 26]
# ['Transdisziplinäre Kunst', 'Gesamt', '2017', 16]
# ['Transdisziplinäre Kunst', 'Gesamt', '2016', 21]
# ['Umweltbiotechnologie', 'Universität Wien', '2018', 1]
# ['Umweltbiotechnologie', 'Universität Wien', '2016', 1]
# ['Umweltbiotechnologie', 'Medizinische Universität Graz', '2018', 0]
# ['Umweltbiotechnologie', 'Technische Universität Wien', '2018', 2]
# ['Umweltbiotechnologie', 'Technische Universität Wien', '2017', 0]
# ['Umweltbiotechnologie', 'Technische Universität Wien', '2016', 1]
# ['Umweltbiotechnologie', 'Technische Universität Graz', '2018', 5]
# ['Umweltbiotechnologie', 'Technische Universität Graz', '2017', 8]
# ['Umweltbiotechnologie', 'Technische Universität Graz', '2016', 17]
# ['Umweltbiotechnologie', 'Universität für Bodenkultur Wien', '2018', 19]
# ['Umweltbiotechnologie', 'Universität für Bodenkultur Wien', '2017', 24]
# ['Umweltbiotechnologie', 'Universität für Bodenkultur Wien', '2016', 21]
# ['Umweltbiotechnologie', 'Universität für Weiterbildung Krems', '2018', 1]
# ['Umweltbiotechnologie', 'Universität für Weiterbildung Krems', '2017', 1]
# ['Umweltbiotechnologie', 'Universität für Weiterbildung Krems', '2016', 1]
# ['Umweltbiotechnologie', 'Gesamt', '2018', 28]
# ['Umweltbiotechnologie', 'Gesamt', '2017', 32]
# ['Umweltbiotechnologie', 'Gesamt', '2016', 40]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Wien', '2018', 4]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Wien', '2017', 4]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Wien', '2016', 9]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Innsbruck', '2018', 47]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Innsbruck', '2017', 60]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Innsbruck', '2016', 46]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Medizinische Universität Innsbruck', '2016', 0]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Salzburg', '2018', 25]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Salzburg', '2017', 43]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Salzburg', '2016', 51]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Wien', '2018', 260]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Wien', '2017', 308]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Wien', '2016', 293]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Graz', '2018', 65]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Graz', '2017', 49]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Technische Universität Graz', '2016', 67]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Montanuniversität Leoben', '2018', 156]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Montanuniversität Leoben', '2017', 106]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Montanuniversität Leoben', '2016', 95]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität für Bodenkultur Wien', '2018', 52]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität für Bodenkultur Wien', '2017', 48]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität für Bodenkultur Wien', '2016', 38]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Linz', '2018', 7]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Linz', '2017', 9]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Linz', '2016', 11]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Klagenfurt', '2018', 2]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Klagenfurt', '2017', 0]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Klagenfurt', '2016', 0]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Mozarteum Salzburg', '2018', 2]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität Mozarteum Salzburg', '2017', 1]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Universität für Weiterbildung Krems', '2018', 2]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Gesamt', '2018', 619]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Gesamt', '2017', 629]
# ['Umweltingenieurwesen, Angewandte Geowissenschaften', 'Gesamt', '2016', 610]
# ['Veterinärmedizin', 'Universität Wien', '2018', 1]
# ['Veterinärmedizin', 'Universität Wien', '2017', 0]
# ['Veterinärmedizin', 'Universität Wien', '2016', 1]
# ['Veterinärmedizin', 'Medizinische Universität Wien', '2018', 1]
# ['Veterinärmedizin', 'Medizinische Universität Wien', '2017', 1]
# ['Veterinärmedizin', 'Medizinische Universität Wien', '2016', 0]
# ['Veterinärmedizin', 'Universität Salzburg', '2017', 1]
# ['Veterinärmedizin', 'Universität Salzburg', '2016', 1]
# ['Veterinärmedizin', 'Universität für Bodenkultur Wien', '2018', 14]
# ['Veterinärmedizin', 'Universität für Bodenkultur Wien', '2017', 11]
# ['Veterinärmedizin', 'Universität für Bodenkultur Wien', '2016', 11]
# ['Veterinärmedizin', 'Veterinärmedizinische Universität Wien', '2018', 890]
# ['Veterinärmedizin', 'Veterinärmedizinische Universität Wien', '2017', 822]
# ['Veterinärmedizin', 'Veterinärmedizinische Universität Wien', '2016', 902]
# ['Veterinärmedizin', 'Gesamt', '2018', 905]
# ['Veterinärmedizin', 'Gesamt', '2017', 836]
# ['Veterinärmedizin', 'Gesamt', '2016', 915]
# ['Werkstofftechnik', 'Universität Wien', '2018', 9]
# ['Werkstofftechnik', 'Universität Wien', '2017', 4]
# ['Werkstofftechnik', 'Universität Wien', '2016', 7]
# ['Werkstofftechnik', 'Medizinische Universität Wien', '2018', 2]
# ['Werkstofftechnik', 'Medizinische Universität Wien', '2016', 1]
# ['Werkstofftechnik', 'Technische Universität Wien', '2018', 33]
# ['Werkstofftechnik', 'Technische Universität Wien', '2017', 47]
# ['Werkstofftechnik', 'Technische Universität Wien', '2016', 46]
# ['Werkstofftechnik', 'Technische Universität Graz', '2018', 71]
# ['Werkstofftechnik', 'Technische Universität Graz', '2017', 34]
# ['Werkstofftechnik', 'Technische Universität Graz', '2016', 33]
# ['Werkstofftechnik', 'Montanuniversität Leoben', '2018', 190]
# ['Werkstofftechnik', 'Montanuniversität Leoben', '2017', 206]
# ['Werkstofftechnik', 'Montanuniversität Leoben', '2016', 218]
# ['Werkstofftechnik', 'Universität für Bodenkultur Wien', '2018', 4]
# ['Werkstofftechnik', 'Universität für Bodenkultur Wien', '2017', 7]
# ['Werkstofftechnik', 'Universität für Bodenkultur Wien', '2016', 6]
# ['Werkstofftechnik', 'Universität Linz', '2018', 17]
# ['Werkstofftechnik', 'Universität Linz', '2017', 21]
# ['Werkstofftechnik', 'Universität Linz', '2016', 16]
# ['Werkstofftechnik', 'Universität Klagenfurt', '2018', 4]
# ['Werkstofftechnik', 'Universität für angewandte Kunst Wien', '2018', 1]
# ['Werkstofftechnik', 'Universität für angewandte Kunst Wien', '2017', 1]
# ['Werkstofftechnik', 'Universität für angewandte Kunst Wien', '2016', 2]
# ['Werkstofftechnik', 'Gesamt', '2018', 329]
# ['Werkstofftechnik', 'Gesamt', '2017', 319]
# ['Werkstofftechnik', 'Gesamt', '2016', 328]
# ['Wirtschaftswissenschaften', 'Universität Wien', '2018', 222]
# ['Wirtschaftswissenschaften', 'Universität Wien', '2017', 239]
# ['Wirtschaftswissenschaften', 'Universität Wien', '2016', 241]
# ['Wirtschaftswissenschaften', 'Universität Graz', '2018', 287]
# ['Wirtschaftswissenschaften', 'Universität Graz', '2017', 273]
# ['Wirtschaftswissenschaften', 'Universität Graz', '2016', 281]
# ['Wirtschaftswissenschaften', 'Universität Innsbruck', '2018', 173]
# ['Wirtschaftswissenschaften', 'Universität Innsbruck', '2017', 160]
# ['Wirtschaftswissenschaften', 'Universität Innsbruck', '2016', 163]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Wien', '2018', 1]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Wien', '2017', 2]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Wien', '2016', 0]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Graz', '2018', 0]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Graz', '2017', 1]
# ['Wirtschaftswissenschaften', 'Medizinische Universität Graz', '2016', 1]
# ['Wirtschaftswissenschaften', 'Universität Salzburg', '2018', 54]
# ['Wirtschaftswissenschaften', 'Universität Salzburg', '2017', 50]
# ['Wirtschaftswissenschaften', 'Universität Salzburg', '2016', 56]
# ['Wirtschaftswissenschaften', 'Technische Universität Wien', '2018', 87]
# ['Wirtschaftswissenschaften', 'Technische Universität Wien', '2017', 63]
# ['Wirtschaftswissenschaften', 'Technische Universität Wien', '2016', 95]
# ['Wirtschaftswissenschaften', 'Technische Universität Graz', '2018', 60]
# ['Wirtschaftswissenschaften', 'Technische Universität Graz', '2017', 64]
# ['Wirtschaftswissenschaften', 'Technische Universität Graz', '2016', 53]
# ['Wirtschaftswissenschaften', 'Montanuniversität Leoben', '2018', 20]
# ['Wirtschaftswissenschaften', 'Montanuniversität Leoben', '2017', 32]
# ['Wirtschaftswissenschaften', 'Montanuniversität Leoben', '2016', 33]
# ['Wirtschaftswissenschaften', 'Universität für Bodenkultur Wien', '2018', 115]
# ['Wirtschaftswissenschaften', 'Universität für Bodenkultur Wien', '2017', 72]
# ['Wirtschaftswissenschaften', 'Universität für Bodenkultur Wien', '2016', 69]
# ['Wirtschaftswissenschaften', 'Wirtschaftsuniversität Wien', '2018', 852]
# ['Wirtschaftswissenschaften', 'Wirtschaftsuniversität Wien', '2017', 762]
# ['Wirtschaftswissenschaften', 'Wirtschaftsuniversität Wien', '2016', 670]
# ['Wirtschaftswissenschaften', 'Universität Linz', '2018', 307]
# ['Wirtschaftswissenschaften', 'Universität Linz', '2017', 311]
# ['Wirtschaftswissenschaften', 'Universität Linz', '2016', 296]
# ['Wirtschaftswissenschaften', 'Universität Klagenfurt', '2018', 130]
# ['Wirtschaftswissenschaften', 'Universität Klagenfurt', '2017', 136]
# ['Wirtschaftswissenschaften', 'Universität Klagenfurt', '2016', 128]
# ['Wirtschaftswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2018', 4]
# ['Wirtschaftswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2017', 4]
# ['Wirtschaftswissenschaften', 'Universität für Musik und darstellende Kunst Wien', '2016', 3]
# ['Wirtschaftswissenschaften', 'Universität Mozarteum Salzburg', '2017', 1]
# ['Wirtschaftswissenschaften', 'Akademie der bildenden Künste Wien', '2018', 3]
# ['Wirtschaftswissenschaften', 'Universität für Weiterbildung Krems', '2018', 18]
# ['Wirtschaftswissenschaften', 'Universität für Weiterbildung Krems', '2017', 5]
# ['Wirtschaftswissenschaften', 'Universität für Weiterbildung Krems', '2016', 11]
# ['Wirtschaftswissenschaften', 'Gesamt', '2018', 2331]
# ['Wirtschaftswissenschaften', 'Gesamt', '2017', 2174]
# ['Wirtschaftswissenschaften', 'Gesamt', '2016', 2100]
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/3.B.1_Universitätsausrichtung.csv
# Output()

# %%
import os, time, datetime, locale

path = '.'
output = widgets.Output()
display(widgets.HTML('<h3>Vorhandene Daten</h3>'), output)
for ind_name in indicators.keys():
    files = [i for i in os.listdir(path) if ind_name in i and '.csv' in i]
    for file in files:
        modified = datetime.datetime.fromtimestamp(os.path.getmtime(file))
        prefix = str(modified.date()) + ": "
        display(FileLink(file, result_html_prefix=prefix))
# Out:
# HTML(value='<h3>Vorhandene Daten</h3>')
# Output()
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_Sitz.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_WZW.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_Disziplin.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Sitz.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_WZW_new.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/3.B.1_WZW.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/3.B.1_Universitätsausrichtung.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/3.B.1_Publikationstyp.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/3.B.1_Disziplin.csv
