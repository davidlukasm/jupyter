# %%
import re
import csv
import requests
import urllib
import json
import html
import time
from bs4 import BeautifulSoup

report_url_base = "https://suasprod.noc-science.at/XLCubedWeb/WebForm/ShowReport.aspx?rep="

indicators = { "1.C.1": {'name': "1.C.1", 'desc': "Drittmittelerlöse",
                         'report_path': "009 wissensbilanzen universitäten/003 intellektuelles vermögen - strukturkapital/002 1-c-1 erlöse forschung und entwicklung-projekte - projekte eek.xml",
                         'dimensions': ["Universitätsausrichtung", "Fördergeber", "Sitz", "Disziplin", "WZW"]},
               "1.C.2": {'name': "1.C.2", 'desc': "Forschungsinfrastruktusr",
                         'report_path': "009 wissensbilanzen universitäten/003 intellektuelles vermögen - strukturkapital/003 1-c-2 investitionen in infrastruktur im f und e bereich.xml",
                         'dimensions': ["Art der FI", "Disziplin", "WZW"]},
               "2.B.1": {'name': "2.B.1", 'desc': "Strukturierte Doktorate",
                         'report_path': "009 wissensbilanzen universitäten/005 kernprozesse - forschung und entwicklung entwicklung und erschließung der künste/002 2-b-1 doktoratsstudierende mit beschäftigungsverhältnis zur universität.xml",
                         'dimensions': ["Personalkategorie", "Staat", "Universitätsausrichtung"]},
               "3.B.1": {'name': "3.B.1", 'desc': "Publikationen",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/001 3-b-1 wissenschaftliche künstlerische veröffentlichungen.xml",
                         'dimensions': ["WZW", "Disziplin", "Publikationstyp", "Universitätsausrichtung"]},
               "3.B.2": {'name': "3.B.2", 'desc': "Vorträge",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/002 3-b-2 gehaltene vorträge präsentationen.xml",
                         'dimensions': ["WZW", "Disziplin", "Veranstaltungstypus", "Vortragstypus", "Universitätsausrichtung"]},
               "3.B.3": {'name': "3.B.3", 'desc': "Patente",
                         'report_path': "009 wissensbilanzen universitäten/007 output und wirkungen der kernprozesse - forschung und entwicklung- und erschließung der künste/003 3-b-3 anzahl der patentanmeldungen.xml",
                         'dimensions': ["Transferleistung"]}}
for indicator in indicators.values():
    indicator['report_url'] = report_url_base + urllib.parse.quote(indicator['report_path'])
    
def create_filename(name, groups):
    return name + '_' + '_'.join(groups) + '.csv'
    
class Unidata:
    workbook = "https://suasprod.noc-science.at/XLCubedWeb/WebServices/WorkbookService.svc/"
    university_class = 's22'
    value_class = 's39'
    aggregate_category = 'Gesamt'
    years = {"2018": 0, "2017": 2, "2016": 4}
    cookie = None
    headers = {
        'Accept': '*/*',
        'Connection': 'keep-alive',
        'Host': 'suasprod.noc-science.at',
        'X-Requested-With': 'XMLHttpRequest',
        'Content-Type': 'application/json; charset=utf-8',
        'Cookie': None,   
    }
    
    def __init__(self):
        self.load_url = self.workbook + "LoadAndRender"
        self.update_url = self.workbook + "UpdateAndRender"
    
    def create_table(self, indicator_name):
        indicator = indicators[indicator_name]
        print("Connecting to uni:data")
        if self.cookie is None:
            report_url = indicator['report_url']
            response = requests.get(report_url)
            self.cookie = response.headers['Set-Cookie'][:response.headers['Set-Cookie'].find(';')]
            self.headers['Cookie'] = self.cookie
        
        print("Creating table")
        report_path = indicator['report_path']
        data = {"Path":report_path,
                "renderMode":0,"Dpi":96,
                "ParameterNames":["rep"],
                "ParameterValues":[report_path]}
        r = requests.post(self.load_url, headers=self.headers, data=json.dumps(data))
        answer = r.json()
        return Table(self, indicator, answer)
    
class Table:
    def __init__(self, unidata, indicator, answer):
        self.unidata = unidata
        self.indicator = indicator
        tabID_find = "this.TabID = \""
        tabID = answer['d'][2]
        tabID = tabID[tabID.find(tabID_find)+len(tabID_find):tabID.find(tabID_find) + len(tabID_find) + 36]
        self.tableID = tabID
        self.groups = self.__get_groups(BeautifulSoup(answer['d'][0]))

    def __get_groups(self, soup):
        groups = {}
        for dim_id, dim_name in enumerate(self.indicator['dimensions']):
            dimslice = soup.find('div',attrs={'class': 'dimslice', 'dimensionslicerid': dim_id})
            groups[dim_name] = {'uid': dimslice['guid'],
                                'categories': {}}
            for idx, option in enumerate(dimslice.find_all('option')):
                if idx == 0:
                    groups[dim_name]['default_category'] = option['value']
                option_name = option.text
                i = 2
                while option_name in groups[dim_name]['categories']:
                    option_name = option.text + ' (' + str(i) + ')'
                    i+=1
                groups[dim_name]['categories'][option_name] = option['value']
        return groups
    
    def __change_category (self, group, category):
        data = {"TabID": self.tableID,
                "ReportPath": self.indicator['report_path'],
                "ServerEvent":"DimensionSlicerChanged",
                "ReportPathWithParameters": "null",
                "Names":["_Guid","_Member","_chartprops","_mapprops"],
                "Values":[group['uid'], category,"",""]}
        retval = requests.post(self.unidata.update_url, headers=self.unidata.headers, data=json.dumps(data))  
        time.sleep(0.6)
        return retval
    
    def __reset_group (self, group): 
        if self.unidata.aggregate_category in group['categories']:
            return self.__change_category(group, group['categories'][self.unidata.aggregate_category])
        else:
            return self.__change_category(group, group['default_category'])
    
    def __get_data_soup (self, group, category):   
        r = self.__change_category(group, category)
        answer = r.json()
        soup = BeautifulSoup(answer['d'][0])
        return soup
            
    def __get_table_data(self, soup):
        universities = {}
        for entry in soup.find_all('td', class_=self.unidata.university_class):
            values = entry.find_next_siblings('td', class_=self.unidata.value_class)
            university = {}
            for year, year_column in self.unidata.years.items():
                try:
                    university[year] = int(re.sub('[^\-0-9]','', values[year_column].text))
                except:
                    university[year] = None
            universities[entry.text.strip()] = university      
        return universities    

    def __get_data (self, groups, level = 0):
        assert(len(groups) >= 1)
        group = self.groups[groups[0]]
        data = {}
        for cat_name, cat_id in group['categories'].items():
            print('\t'*level + cat_name)
            if len(groups) == 1:
                soup = self.__get_data_soup(group, cat_id)
                data[cat_name] = self.__get_table_data(soup)
            else:
                self.__change_category(group, cat_id)
                data[cat_name] = self.__get_data(groups[1:], level+1)
                
        self.__reset_group(group)
        return data    
    
    def __save_rows_helper(data, higher_groups, groups, csvw):            
        for group_name, group in data.items():
            if len(groups) == 0:
                uni_name = group_name
                for year_name, value in group.items():
                    if value is not None:
                        csvw.writerow(higher_groups + [uni_name, year_name, value])
                        print(higher_groups + [uni_name, year_name, value])
            else:
                Table.__save_rows_helper(group, higher_groups+[group_name], groups[1:], csvw)

    def __save_table_helper (data, groups, csvw):
        csvw.writerow(groups + ['Universität', 'Jahr', 'Wert'])
        groups.reverse()
        return Table.__save_rows_helper(data, [], groups, csvw)
    
    def download_all(self, groups, filename=None):
        print("Downloading data")
        data = self.__get_data(groups)
        if filename is None:
            filename = create_filename(indicator['name'], groups)
        with open(filename, 'w') as csv_file:
            csvw = csv.writer(csv_file, delimiter=';')
            Table.__save_table_helper(data, groups, csvw)
        return filename

# %%
import ipywidgets as widgets
import os
from IPython.display import display
from IPython.display import FileLink, FileLinks, Javascript


    
class Selector:
    indicator_selector = widgets.Dropdown(
        options = [('Auswählen...', -1)] +
                  [(indicator['name']+' - '+indicator['desc'], indicator['name']) for indicator in indicators.values()],
    )
    dimension_selector = widgets.SelectMultiple(
        options = [('Bitte zuerst Kennzahl auswählen', -1)]
    )
    execute_button = widgets.Button(
        description='Laden', disabled=True,
        tooltip = 'Bitte Indikator und Dimensionen auswählen',
        button_style='info'
    )
    filename_text = widgets.Text(placeholder='Dateiname')
        
    indicator = None
    dimensions = None
    
    def indicator_selected(self, ind_sel):
        self.indicator = indicators[ind_sel['new']]
        self.dimension_selector.options = [(dim_name, idx) for idx, dim_name in enumerate(self.indicator['dimensions'])]

    def dimension_selected(self, dim_sel):
        self.dimensions = list(dim_sel['new'])
        if len(self.dimensions) == 0:
            self.execute_button.disabled = True
            self.execute_button.tooltip = 'Bitte Indikator und Dimensionen auswählen'
        else:
            self.execute_button.disabled = False
            self.execute_button.tooltip = 'Daten herunterladen'
            self.filename_text.value = create_filename(self.indicator['name'], [self.indicator['dimensions'][i] for i in self.dimensions])
        
    def execute(self, button):
        self.execute_button.disabled = True
        self.save()
        display(Javascript("Jupyter.notebook.execute_cells([2])"))
    
    def __init__(self):
        self.indicator_selector.observe(self.indicator_selected, names='value')
        self.dimension_selector.observe(self.dimension_selected, names='index')
        self.execute_button.on_click(self.execute)
        self.output = widgets.Output()
        self.box = widgets.VBox(
            [ widgets.HBox([widgets.Label("Kennzahl: "),
                            self.indicator_selector]),
              widgets.VBox([widgets.Label('Zu exportierende Dimensionen:'),
                               self.dimension_selector]),
             
              self.filename_text,
              self.execute_button])
        display(self.box, self.output)
        
            
    def save(self):
        print("Bitte warten...")
        unidata = Unidata()
        kennzahl = unidata.create_table(self.indicator['name'])
        file = kennzahl.download_all([self.indicator['dimensions'][i] for i in self.dimensions], self.filename_text.value)
        link = FileLink(file)
        display(link, self.output)
        
output = widgets.Output()
display(widgets.HTML('<h3>Neuer Datenexport</h3>'), output)
selector = Selector()
# Out:
# HTML(value='<h3>Neuer Datenexport</h3>')
# Output()
# VBox(children=(HBox(children=(Label(value='Kennzahl: '), Dropdown(options=(('Auswählen...', -1), ('1.C.1 - Dri…
# Output()
# Bitte warten...
# Connecting to uni:data
# Creating table
# Downloading data
# Gesamt
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# nicht bekannt / nicht zuordenbar
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# EU
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Bund (Ministerien)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Länder (inkl. deren Stiftungen und Einrichtungen)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Gemeinden und Gemeindeverbände (ohne Wien)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# FWF
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# sonstige vorwiegend aus Bundesmitteln getragene Fördereinrichtungen (FFG)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Unternehmen
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Gesetzliche Interessenvertretungen
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Stiftungen/Fonds/Sonstige Fördereinrichtungen
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# sonstige
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# andere internationale Organisationen
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# FFG
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# ÖAW
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Jubiläumsfonds der ÖNB
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# sonstige öffentlich-rechtliche Einrichtungen (Körperschaften, Stiftungen, Fonds etc.)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# Private (Stiftungen, Vereine, etc.)
# 	Gesamt
# 	AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN
# 	BILDENDE KUNST / GESTALTENDE KUNST
# 	DARSTELLENDE KUNST
# 	GEISTESWISSENSCHAFTEN
# 	HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN
# 	MUSIK
# 	NATURWISSENSCHAFTEN
# 	SOZIALWISSENSCHAFTEN
# 	TECHNISCHE WISSENSCHAFTEN
# ['Gesamt', 'Gesamt', 'Universität Wien', '2018', 85079393]
# ['Gesamt', 'Gesamt', 'Universität Wien', '2017', 79842908]
# ['Gesamt', 'Gesamt', 'Universität Wien', '2016', 79994603]
# ['Gesamt', 'Gesamt', 'Universität Graz', '2018', 27990716]
# ['Gesamt', 'Gesamt', 'Universität Graz', '2017', 26935219]
# ['Gesamt', 'Gesamt', 'Universität Graz', '2016', 24973630]
# ['Gesamt', 'Gesamt', 'Universität Innsbruck', '2018', 49411951]
# ['Gesamt', 'Gesamt', 'Universität Innsbruck', '2017', 44440286]
# ['Gesamt', 'Gesamt', 'Universität Innsbruck', '2016', 43695849]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Wien', '2018', 99006332]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Wien', '2017', 95284358]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Wien', '2016', 84001641]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Graz', '2018', 50315258]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Graz', '2017', 49381211]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Graz', '2016', 48759864]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Innsbruck', '2018', 42161070]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Innsbruck', '2017', 36365574]
# ['Gesamt', 'Gesamt', 'Medizinische Universität Innsbruck', '2016', 39075918]
# ['Gesamt', 'Gesamt', 'Universität Salzburg', '2018', 19026512]
# ['Gesamt', 'Gesamt', 'Universität Salzburg', '2017', 25425840]
# ['Gesamt', 'Gesamt', 'Universität Salzburg', '2016', 24030051]
# ['Gesamt', 'Gesamt', 'Technische Universität Wien', '2018', 87315875]
# ['Gesamt', 'Gesamt', 'Technische Universität Wien', '2017', 83562305]
# ['Gesamt', 'Gesamt', 'Technische Universität Wien', '2016', 88849581]
# ['Gesamt', 'Gesamt', 'Technische Universität Graz', '2018', 78874272]
# ['Gesamt', 'Gesamt', 'Technische Universität Graz', '2017', 70469363]
# ['Gesamt', 'Gesamt', 'Technische Universität Graz', '2016', 69365275]
# ['Gesamt', 'Gesamt', 'Montanuniversität Leoben', '2018', 43906000]
# ['Gesamt', 'Gesamt', 'Montanuniversität Leoben', '2017', 37727720]
# ['Gesamt', 'Gesamt', 'Montanuniversität Leoben', '2016', 33456705]
# ['Gesamt', 'Gesamt', 'Universität für Bodenkultur Wien', '2018', 47836780]
# ['Gesamt', 'Gesamt', 'Universität für Bodenkultur Wien', '2017', 45023447]
# ['Gesamt', 'Gesamt', 'Universität für Bodenkultur Wien', '2016', 50937182]
# ['Gesamt', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2018', 17281518]
# ['Gesamt', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2017', 13974306]
# ['Gesamt', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2016', 14973094]
# ['Gesamt', 'Gesamt', 'Wirtschaftsuniversität Wien', '2018', 12865283]
# ['Gesamt', 'Gesamt', 'Wirtschaftsuniversität Wien', '2017', 13224985]
# ['Gesamt', 'Gesamt', 'Wirtschaftsuniversität Wien', '2016', 12224198]
# ['Gesamt', 'Gesamt', 'Universität Linz', '2018', 29256355]
# ['Gesamt', 'Gesamt', 'Universität Linz', '2017', 31888847]
# ['Gesamt', 'Gesamt', 'Universität Linz', '2016', 31415613]
# ['Gesamt', 'Gesamt', 'Universität Klagenfurt', '2018', 7540715]
# ['Gesamt', 'Gesamt', 'Universität Klagenfurt', '2017', 6873775]
# ['Gesamt', 'Gesamt', 'Universität Klagenfurt', '2016', 7429918]
# ['Gesamt', 'Gesamt', 'Universität für angewandte Kunst Wien', '2018', 2134215]
# ['Gesamt', 'Gesamt', 'Universität für angewandte Kunst Wien', '2017', 2453667]
# ['Gesamt', 'Gesamt', 'Universität für angewandte Kunst Wien', '2016', 2807556]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2018', 1118639]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2017', 834522]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2016', 964193]
# ['Gesamt', 'Gesamt', 'Universität Mozarteum Salzburg', '2018', 1300304]
# ['Gesamt', 'Gesamt', 'Universität Mozarteum Salzburg', '2017', 1151405]
# ['Gesamt', 'Gesamt', 'Universität Mozarteum Salzburg', '2016', 1082322]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2018', 1436908]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2017', 1342056]
# ['Gesamt', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2016', 1153165]
# ['Gesamt', 'Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2018', 1627101]
# ['Gesamt', 'Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2017', 738579]
# ['Gesamt', 'Gesamt', 'Universität für künstlerische und industrielle Gestaltung Linz', '2016', 1210088]
# ['Gesamt', 'Gesamt', 'Akademie der bildenden Künste Wien', '2018', 1601654]
# ['Gesamt', 'Gesamt', 'Akademie der bildenden Künste Wien', '2017', 1399721]
# ['Gesamt', 'Gesamt', 'Akademie der bildenden Künste Wien', '2016', 1352603]
# ['Gesamt', 'Gesamt', 'Universität für Weiterbildung Krems', '2018', 6569060]
# ['Gesamt', 'Gesamt', 'Universität für Weiterbildung Krems', '2017', 4846793]
# ['Gesamt', 'Gesamt', 'Universität für Weiterbildung Krems', '2016', 8227180]
# ['Gesamt', 'Gesamt', 'Gesamt', '2018', 713655911]
# ['Gesamt', 'Gesamt', 'Gesamt', '2017', 673186887]
# ['Gesamt', 'Gesamt', 'Gesamt', '2016', 669980227]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2018', 114776]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2017', 151334]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2016', 106069]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Medizinische Universität Graz', '2018', 44201]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Medizinische Universität Graz', '2017', 428]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Medizinische Universität Graz', '2016', 0]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Salzburg', '2018', 0]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Salzburg', '2017', 0]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Salzburg', '2016', 18529]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2018', 500]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2017', 47336]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2016', 29913]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Montanuniversität Leoben', '2018', 14127]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Montanuniversität Leoben', '2017', 19375]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Montanuniversität Leoben', '2016', 20673]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2018', 8373983]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2017', 7931460]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2016', 7928543]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Veterinärmedizinische Universität Wien', '2018', 11550872]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Veterinärmedizinische Universität Wien', '2017', 9128803]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Veterinärmedizinische Universität Wien', '2016', 10748626]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Klagenfurt', '2018', 87968]
# ['Gesamt', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität

# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Wien', '2018', 43200037]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Wien', '2017', 40356733]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Wien', '2016', 43946544]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Graz', '2018', 48702266]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Graz', '2017', 43108132]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Technische Universität Graz', '2016', 39690713]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Montanuniversität Leoben', '2018', 38605746]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Montanuniversität Leoben', '2017', 31463818]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Montanuniversität Leoben', '2016', 26269626]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 11575880]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2017', 10883907]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2016', 13089306]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Linz', '2018', 11433661]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Linz', '2017', 12973519]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Linz', '2016', 11677344]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Klagenfurt', '2018', 807807]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Klagenfurt', '2017', 638950]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität Klagenfurt', '2016', 595027]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für angewandte Kunst Wien', '2018', 230731]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für angewandte Kunst Wien', '2017', 140869]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für angewandte Kunst Wien', '2016', 57882]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Musik und darstellende Kunst Graz', '2018', 188631]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Musik und darstellende Kunst Graz', '2017', 320111]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Musik und darstellende Kunst Graz', '2016', 251007]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Weiterbildung Krems', '2018', 1297498]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Weiterbildung Krems', '2017', 1055800]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Weiterbildung Krems', '2016', 2337536]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Gesamt', '2018', 170837876]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Gesamt', '2017', 154392873]
# ['Gesamt', 'TECHNISCHE WISSENSCHAFTEN', 'Gesamt', '2016', 149685189]
# ['nicht bekannt / nicht zuordenbar', 'Gesamt', 'Universität für Bodenkultur Wien', '2018', 112088]
# ['nicht bekannt / nicht zuordenbar', 'Gesamt', 'Gesamt', '2018', 112088]
# ['nicht bekannt / nicht zuordenbar', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2018', 4103]
# ['nicht bekannt / nicht zuordenbar', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Gesamt', '2018', 4103]
# ['nicht bekannt / nicht zuordenbar', 'GEISTESWISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 438]
# ['nicht bekannt / nicht zuordenbar', 'GEISTESWISSENSCHAFTEN', 'Gesamt', '2018', 438]
# ['nicht bekannt / nicht zuordenbar', 'HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 34246]
# ['nicht bekannt / nicht zuordenbar', 'HUMANMEDIZIN, GESUNDHEITSWISSENSCHAFTEN', 'Gesamt', '2018', 34246]
# ['nicht bekannt / nicht zuordenbar', 'NATURWISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 20477]
# ['nicht bekannt / nicht zuordenbar', 'NATURWISSENSCHAFTEN', 'Gesamt', '2018', 20477]
# ['nicht bekannt / nicht zuordenbar', 'SOZIALWISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 8946]
# ['nicht bekannt / nicht zuordenbar', 'SOZIALWISSENSCHAFTEN', 'Gesamt', '2018', 8946]
# ['nicht bekannt / nicht zuordenbar', 'TECHNISCHE WISSENSCHAFTEN', 'Universität für Bodenkultur Wien', '2018', 43878]
# ['nicht bekannt / nicht zuordenbar', 'TECHNISCHE WISSENSCHAFTEN', 'Gesamt', '2018', 43878]
# ['EU', 'Gesamt', 'Universität Wien', '2018', 13633780]
# ['EU', 'Gesamt', 'Universität Wien', '2017', 13814218]
# ['EU', 'Gesamt', 'Universität Wien', '2016', 14361829]
# ['EU', 'Gesamt', 'Universität Graz', '2018', 2907787]
# ['EU', 'Gesamt', 'Universität Graz', '2017', 2539494]
# ['EU', 'Gesamt', 'Universität Graz', '2016', 1781152]
# ['EU', 'Gesamt', 'Universität Innsbruck', '2018', 8544358]
# ['EU', 'Gesamt', 'Universität Innsbruck', '2017', 6282070]
# ['EU', 'Gesamt', 'Universität Innsbruck', '2016', 6070130]
# ['EU', 'Gesamt', 'Medizinische Universität Wien', '2018', 8347843]
# ['EU', 'Gesamt', 'Medizinische Universität Wien', '2017', 8417657]
# ['EU', 'Gesamt', 'Medizinische Universität Wien', '2016', 6389023]
# ['EU', 'Gesamt', 'Medizinische Universität Graz', '2018', 2149800]
# ['EU', 'Gesamt', 'Medizinische Universität Graz', '2017', 1869814]
# ['EU', 'Gesamt', 'Medizinische Universität Graz', '2016', 2381982]
# ['EU', 'Gesamt', 'Medizinische Universität Innsbruck', '2018', 3169484]
# ['EU', 'Gesamt', 'Medizinische Universität Innsbruck', '2017', 3371281]
# ['EU', 'Gesamt', 'Medizinische Universität Innsbruck', '2016', 2265799]
# ['EU', 'Gesamt', 'Universität Salzburg', '2018', 3069169]
# ['EU', 'Gesamt', 'Universität Salzburg', '2017', 4137045]
# ['EU', 'Gesamt', 'Universität Salzburg', '2016', 3839851]
# ['EU', 'Gesamt', 'Technische Universität Wien', '2018', 14732400]
# ['EU', 'Gesamt', 'Technische Universität Wien', '2017', 13560680]
# ['EU', 'Gesamt', 'Technische Universität Wien', '2016', 16365121]
# ['EU', 'Gesamt', 'Technische Universität Graz', '2018', 11016518]
# ['EU', 'Gesamt', 'Technische Universität Graz', '2017', 8535365]
# ['EU', 'Gesamt', 'Technische Universität Graz', '2016', 9309967]
# ['EU', 'Gesamt', 'Montanuniversität Leoben', '2018', 3460400]
# ['EU', 'Gesamt', 'Montanuniversität Leoben', '2017', 2297016]
# ['EU', 'Gesamt', 'Montanuniversität Leoben', '2016', 2387876]
# ['EU', 'Gesamt', 'Universität für Bodenkultur Wien', '2018', 7516955]
# ['EU', 'Gesamt', 'Universität für Bodenkultur Wien', '2017', 4699102]
# ['EU', 'Gesamt', 'Universität für Bodenkultur Wien', '2016', 11896536]
# ['EU', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2018', 599004]
# ['EU', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2017', 60000]
# ['EU', 'Gesamt', 'Veterinärmedizinische Universität Wien', '2016', 1176978]
# ['EU', 'Gesamt', 'Wirtschaftsuniversität Wien', '2018', 2070273]
# ['EU', 'Gesamt', 'Wirtschaftsuniversität Wien', '2017', 2038773]
# ['EU', 'Gesamt', 'Wirtschaftsuniversität Wien', '2016', 1922160]
# ['EU', 'Gesamt', 'Universität Linz', '2018', 2277618]
# ['EU', 'Gesamt', 'Universität Linz', '2017', 4005468]
# ['EU', 'Gesamt', 'Universität Linz', '2016', 2482011]
# ['EU', 'Gesamt', 'Universität Klagenfurt', '2018', 1024246]
# ['EU', 'Gesamt', 'Universität Klagenfurt', '2017', 770136]
# ['EU', 'Gesamt', 'Universität Klagenfurt', '2016', 1075816]
# ['EU', 'Gesamt', 'Universität für angewandte Kunst Wien', '2018', 205754]
# ['EU', 'Gesamt', 'Universität für angewandte Kunst Wien', '2017', 250637]
# ['EU', 'Gesamt', 'Universität für angewandte Kunst Wien', '2016', 662105]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2018', 254170]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2017', 23020]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Wien', '2016', 79720]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2018', 0]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2017', 2876]
# ['EU', 'Gesamt', 'Universität für Musik und darstellende Kunst Graz', '2016', 5784]
# ['EU', 'Gesamt', 'Akademie der bildenden Künste Wien', '2018', 0]
# ['EU', 'Gesamt', 'Akademie der bildenden Künste Wien', '2017', 2500]
# ['EU', 'Gesamt', 'Akademie der bildenden Künste Wien', '2016', 0]
# ['EU', 'Gesamt', 'Universität für Weiterbildung Krems', '2018', 811091]
# ['EU', 'Gesamt', 'Universität für Weiterbildung Krems', '2017', 555752]
# ['EU', 'Gesamt', 'Universität für Weiterbildung Krems', '2016', 916933]
# ['EU', 'Gesamt', 'Gesamt', '2018', 85790649]
# ['EU', 'Gesamt', 'Gesamt', '2017', 77232905]
# ['EU', 'Gesamt', 'Gesamt', '2016', 85370774]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2018', 25837]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2017', 16440]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität Wien', '2016', 3705]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2018', 500]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2017', 38129]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Technische Universität Graz', '2016', 27216]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2018', 1357316]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2017', 731969]
# ['EU', 'AGRARWISSENSCHAFTEN, VETERINÄRMEDIZIN', 'Universität für Bodenkultur Wien', '2016', 1315187]
# ...
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Innsbruck', '2016', 37931]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Medizinische Universität Innsbruck', '2018', 1568]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Medizinische Universität Innsbruck', '2017', 1040]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Medizinische Universität Innsbruck', '2016', 6773]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Salzburg', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Salzburg', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Salzburg', '2016', 10450]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Wien', '2018', 155194]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Wien', '2017', 207451]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Wien', '2016', 286300]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Graz', '2018', 264814]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Graz', '2017', 352]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Technische Universität Graz', '2016', 9424]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Montanuniversität Leoben', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Montanuniversität Leoben', '2017', 20750]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Montanuniversität Leoben', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Bodenkultur Wien', '2018', 30540]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Bodenkultur Wien', '2017', 10597]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Bodenkultur Wien', '2016', 20595]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Linz', '2018', 232340]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Linz', '2017', 211462]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität Linz', '2016', 33346]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Musik und darstellende Kunst Graz', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Musik und darstellende Kunst Graz', '2017', 2620]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Musik und darstellende Kunst Graz', '2016', 3360]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Weiterbildung Krems', '2018', 18369]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Weiterbildung Krems', '2017', 56599]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Universität für Weiterbildung Krems', '2016', 108724]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Gesamt', '2018', 1569532]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Gesamt', '2017', 771272]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Physik, Astronomie', 'Gesamt', '2016', 695573]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Wien', '2018', 2370]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Wien', '2017', 29739]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Wien', '2016', 96779]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Innsbruck', '2018', 108943]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Innsbruck', '2017', 86179]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Innsbruck', '2016', 36601]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Salzburg', '2018', 6000]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Salzburg', '2017', 18078]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Salzburg', '2016', 2950]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Bodenkultur Wien', '2018', 5198]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Bodenkultur Wien', '2017', 4076]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Bodenkultur Wien', '2016', 19155]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Linz', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Linz', '2017', 8580]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Linz', '2016', 4470]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Klagenfurt', '2018', 4744]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Klagenfurt', '2017', 1246]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität Klagenfurt', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Weiterbildung Krems', '2018', 2402]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Weiterbildung Krems', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Universität für Weiterbildung Krems', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Gesamt', '2018', 129658]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Gesamt', '2017', 147898]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Politikwissenschaften', 'Gesamt', '2016', 159955]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Wien', '2018', 464284]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Wien', '2017', 386598]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Wien', '2016', 334079]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Graz', '2018', 40487]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Graz', '2017', 3593]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Graz', '2016', 480]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Innsbruck', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Innsbruck', '2017', -578]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Innsbruck', '2016', 8907]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Wien', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Wien', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Wien', '2016', 23871]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Graz', '2018', 14591]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Graz', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Graz', '2016', 10]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Innsbruck', '2018', 9203]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Innsbruck', '2017', 5016]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Medizinische Universität Innsbruck', '2016', 1907]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Salzburg', '2018', 53500]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Salzburg', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Salzburg', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Bodenkultur Wien', '2018', 2973]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Bodenkultur Wien', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Bodenkultur Wien', '2016', 908]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Wirtschaftsuniversität Wien', '2018', 13670]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Wirtschaftsuniversität Wien', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Wirtschaftsuniversität Wien', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Klagenfurt', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Klagenfurt', '2017', 9333]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität Klagenfurt', '2016', 27471]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Musik und darstellende Kunst Graz', '2018', 750]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Musik und darstellende Kunst Graz', '2017', 750]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Musik und darstellende Kunst Graz', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Weiterbildung Krems', '2018', 14432]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Weiterbildung Krems', '2017', 4300]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Universität für Weiterbildung Krems', '2016', 3500]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Gesamt', '2018', 613891]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Gesamt', '2017', 409013]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Psychologie', 'Gesamt', '2016', 401133]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Wien', '2018', 167]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Wien', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Wien', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Graz', '2018', 68645]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Graz', '2017', 38882]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Graz', '2016', 187400]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Innsbruck', '2018', 74325]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Innsbruck', '2017', 282834]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Innsbruck', '2016', 40540]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Salzburg', '2018', 34167]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Salzburg', '2017', 46990]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Salzburg', '2016', 8083]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Wien', '2018', 13807]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Wien', '2017', 10529]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Wien', '2016', 20002]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Graz', '2018', 29]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Graz', '2017', 494]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Technische Universität Graz', '2016', 4725]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Montanuniversität Leoben', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Montanuniversität Leoben', '2017', 1199]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Montanuniversität Leoben', '2016', 899]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität für Bodenkultur Wien', '2018', 10815]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität für Bodenkultur Wien', '2017', 14718]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität für Bodenkultur Wien', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Wirtschaftsuniversität Wien', '2018', 1828]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Wirtschaftsuniversität Wien', '2017', 20379]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Wirtschaftsuniversität Wien', '2016', 27300]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Linz', '2018', 27400]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Linz', '2017', 102245]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Linz', '2016', 87680]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Klagenfurt', '2018', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Klagenfurt', '2017', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Universität Klagenfurt', '2016', 0]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Gesamt', '2018', 231181]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Gesamt', '2017', 518269]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Rechtswissenschaften', 'Gesamt', '2016', 376630]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Universität für Musik und darstellende Kunst Wien', '2018', 4320]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Universität für Musik und darstellende Kunst Wien', '2017', 4320]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Universität für Musik und darstellende Kunst Wien', '2016', 4748]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Gesamt', '2018', 4320]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Gesamt', '2017', 4320]
# ['Länder (inkl. deren Stiftungen und Einrichtungen)', 'Schauspiel', 'Gesamt', '2016', 4748]
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_WZW.csv
# Output()

# %%
import os, time, datetime, locale

path = '.'
output = widgets.Output()
display(widgets.HTML('<h3>Vorhandene Daten</h3>'), output)
for ind_name in indicators.keys():
    files = [i for i in os.listdir(path) if ind_name in i and '.csv' in i]
    for file in files:
        modified = datetime.datetime.fromtimestamp(os.path.getmtime(file))
        prefix = str(modified.date()) + ": "
        display(FileLink(file, result_html_prefix=prefix))
# Out:
# HTML(value='<h3>Vorhandene Daten</h3>')
# Output()
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_Sitz.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_WZW.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_Disziplin.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Sitz.csv
# /home/david/Storage/Computing/Python/datascience/jupyter/scraper/1.C.1_Fördergeber_WZW_new.csv
